# %% [markdown]
# ## Data Loading

# %%
from data_handler import *
from submodular_pick import *
import random
import numpy as np
import nltk
import re
from gensim.models import Doc2Vec
from gensim import corpora
from gensim.models.doc2vec import LabeledSentence
from gensim import summarization
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import accuracy_score
from lime.lime_text import LimeTextExplainer
import operator
from tqdm import tqdm

# %%
reviewData_filepath = 'reviews_Electronics.json'
metaData_filepath = 'meta_Electronics.json'
metadata_df = load_metadata(metaData_filepath)
# Out:
# # Exception occured : 40

# %%
category_counts = metadata_df['categories'].value_counts()

# %%
product_group_name = 'Electronics, Computers & Accessories, Cables & Accessories, Keyboards'

# %%
product_group_review_data = get_reviewdata_of_product_group(product_group_name, metadata_df, reviewData_filepath)
product_group_review_data['label'] = product_group_review_data['overall'].apply(lambda x : 1 if x >= 4 else 0)

# %%
# product_group_review_data['asin'].value_counts()

# %%
product_id = 'B005DKZTMG'

# %%
def clean_punctuation(text):
    text = re.sub('\\!+', '.',text)
    text = re.sub('\\?+', '.',text)
    text = re.sub('\\.+','.',text)
    return text

# %%
product_review = product_group_review_data.loc[product_group_review_data['asin'] == product_id]

product_review['reviewText'] = product_review['reviewText'].apply(lambda x : clean_punctuation(x))

product_review = product_review.loc[product_review['reviewText'].apply(lambda x : len(x.split('.'))>=4)]
product_review = product_review.loc[product_review['reviewText'].apply(lambda x : len(x.split('.'))<=6)]
num_pos = len(product_review.loc[product_review['label'] == 1])
num_neg = len(product_review.loc[product_review['label'] == 0])
resampled_pos = product_review.loc[product_review['label'] == 1].iloc[random.sample(range(0,num_pos),num_neg)].reset_index(drop=True)
product_review = resampled_pos.append(product_review.loc[product_review['label'] == 0]).reset_index(drop=True)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
len(product_review)
# Out:
# 558

# %%
list(product_review.loc[:3,'reviewText'])
# Out:
# ['The wireless Logitech K400 keyboard works great with my Samsung 6100 series tv when I am brousing the internet.  I love the size of the keyboard and the built-in mouse.  It will only work when using the internet and will not work when using netflix or the other apps on the smart tv, but I knew that before I bought it.',
#  'Works fine. not too much for gaming but for a living room pc its great to use. I have used it alot.',
#  "I love the size of the Logitech wireless keyboard. It is easy to use with the multi touch touchpad being a plus.  It's the perfect size and weight to carry from my desk to bed for easy access to what I need. It comes with two AA batteries which was nice and it is the best wireless keyboard I have ever used. I give Logitech Wireless Touch keyboard K400 with built-in Multi-touchTouchpad a five star rating and highly recommend it.",
#  "We have 2 of these and they are great. Batteries haven't been changed since purchased 6 months ago and still good. I even have a pc hooked up to my tv in bedroom and i control it from bed with this keyboard. For the price and quality you cant go wrong."]

# %% [markdown]
# ## Embedding

# %%
def clean_text(text):
    text = text.strip()
    text = text.lower()
    text = re.sub('[^a-z ]', '', text)
    text = re.sub(' +', ' ', text)
    text = ' '.join([word for word in text.split() if word not in stoplist])
    return text

# %%
class Custom_pipeline:
    
    def __init__(self, embedder, predictor):
        self.embedder = embedder
        self.predictor = predictor
        
    def predict_proba(self, x):
        embedded_x = [self.embedder.infer_vector(i.split()) for i in x]
        return self.predictor.predict_proba(embedded_x)
    
    def fit(x,y):
        self.predictor.fit(x,y)

# %%
stoplist = set(nltk.corpus.stopwords.words('english'))

product_review['clean_text'] = product_review['reviewText'].apply(lambda x : clean_text(x))

instances = []
for i in range(len(product_review)):
    instance = LabeledSentence(words=product_review.loc[i,'clean_text'].split(), tags=[str(i)])
    instances.append(instance)

# %%
# for size in [30,50,70,100]:
    
#     for window in [6,8,10,12,14]:

#         model = Doc2Vec(size = size, window = window, workers = 3)
#         model.build_vocab(instances)
#         for epoch in range(20):
#             random.shuffle(instances)
#             model.train(instances)
#         embedded_text = [model.docvecs[str(x)] for x in range(len(product_review))]

#         clf = LogisticRegression(penalty='l1')
#         scores = cross_val_score(clf, embedded_text, product_review['label'], cv=10)
#         print(size,window,epoch,np.mean(scores))

# %%
best_vec_size = 300
best_window_size = 10

model = Doc2Vec(size = best_vec_size, window = best_window_size, workers=10)
model.build_vocab(instances)

for epoch in range(20):
    random.shuffle(instances)
    model.train(instances)
    
embedded_text = [model.docvecs[str(x)] for x in range(len(product_review))]

clf = LogisticRegression(penalty='l1')
scores = cross_val_score(clf, embedded_text, product_review['label'], cv=3)
print(np.mean(scores))

clf.fit(embedded_text, product_review['label'])
p_comp = Custom_pipeline(embedder = model, predictor = clf)
# Out:
# 0.666666666667

# %%
model.most_similar('arrow')
# Out:
# [('enter', 0.45364534854888916),
#  ('press', 0.3771659731864929),
#  ('uparrow', 0.3199821412563324),
#  ('shift', 0.31649765372276306),
#  ('poor', 0.3055460453033447),
#  ('f', 0.2981566786766052),
#  ('pressing', 0.2854941487312317),
#  ('hard', 0.2852557897567749),
#  ('enough', 0.2799328565597534),
#  ('fn', 0.27977943420410156)]

# %% [markdown]
# ## LIME

# %%
class_names = ['negative', 'positive']
explainer = LimeTextExplainer(class_names = class_names)

# %%
% time product_review['explanations'] = product_review['clean_text'].map(lambda x : get_explanation(explainer=explainer,\
                                                                    pipeline = p_comp, instance = x))
# Out:
# Wall time: 51.6 s

# %%
feature_importances = get_feature_importances(list(product_review['explanations']))
features = sorted(feature_importances.items(), key=operator.itemgetter(1), reverse=True)

# %%
features
# Out:
# [('great keyboard', 2.5184846593912829),
#  ('works great', 2.3913055046529514),
#  ('keyboard great', 1.2658916967338401),
#  ('touch pad', 1.26451618423822),
#  ('great product', 1.2368592280101187),
#  ('nice keyboard', 0.97987250207338272),
#  ('key board', 0.8021050905805911),
#  ('keyboard works', 0.62203821787674096),
#  ('keyboard little', 0.61110137621197724),
#  ('bought use', 0.54441564978750534),
#  ('works well', 0.53949160299795174),
#  ('product great', 0.51189674905224603),
#  ('smart tv', 0.47912786336333635),
#  ('purchased use', 0.45450569997386403),
#  ('work great', 0.45185549732099112),
#  ('great little', 0.4442857883459892),
#  ('keyboard perfect', 0.40347247868940517),
#  ('mouse pad', 0.36896264344307117),
#  ('like keyboard', 0.36302648038915375),
#  ('using keyboard', 0.35617054916753377),
#  ('wireless keyboard', 0.34322235848974586),
#  ('keyboard small', 0.33159308687962241),
#  ('great comfy', 0.32708121510334071),
#  ('highly recommended', 0.32024886614280818),
#  ('second one', 0.31973660563053519),
#  ('keyboard right', 0.29853270428934375),
#  ('keyboard ok', 0.29745357944720618),
#  ('found keyboard', 0.29304244945570102),
#  ('little keyboard', 0.29045903332282863),
#  ('great working', 0.28516383006941959),
#  ('living room', 0.26964476197791609),
#  ('easy install', 0.26810195835378753),
#  ('mouse instead', 0.26613198115232489),
#  ('fault keyboard', 0.26549565456358465),
#  ('screen keyboard', 0.26485777919589348),
#  ('great wireless', 0.26100988556478705),
#  ('great taking', 0.25687318667538561),
#  ('great mac', 0.25647658937790196),
#  ('keyboard touch', 0.25131261790241438),
#  ('old keyboard', 0.24836925626134568),
#  ('usb dongle', 0.24705410872522221),
#  ('good keyboard', 0.24667892296655611),
#  ('great everyday', 0.24545725719742367),
#  ('keyboard mouse', 0.24393865205925738),
#  ('great quality', 0.24279864165451501),
#  ('keyboard light', 0.24024784820532799),
#  ('well made', 0.23833013550081325),
#  ('would buy', 0.23747211323932133),
#  ('keyboard rocks', 0.23461738081567787),
#  ('keyboard exactly', 0.23191573687477121),
#  ('around couch', 0.23054120557761507),
#  ('great price', 0.226236608027858),
#  ('light comfortable', 0.22509628498058745),
#  ('keyboard feel', 0.22322146868557169),
#  ('mouse keyboard', 0.22073505056855525),
#  ('laptop keyboard', 0.21987162035275706),
#  ('keyboard perfectly', 0.219549756282124),
#  ('first got', 0.21928899056387341),
#  ('type etc', 0.21660977112068072),
#  ('driver though', 0.21515183665520038),
#  ('keyboard met', 0.21414225884678242),
#  ('track pad', 0.21317495253687735),
#  ('keyboard touchpad', 0.21199914563675715),
#  ('single reception', 0.21192151208086232),
#  ('little cheap', 0.21114887340552901),
#  ('works perfectly', 0.21108722789450485),
#  ('say keyboard', 0.21077208889019186),
#  ('great item', 0.20967055204801016),
#  ('im using', 0.20957000272416532),
#  ('keyboard responsive', 0.20909494088462544),
#  ('pleased product', 0.2076130157850688),
#  ('product purchased', 0.20554388709966237),
#  ('key strokes', 0.20231139661654013),
#  ('great allinone', 0.19995349152738739),
#  ('thing great', 0.19752277871597271),
#  ('keyboard truly', 0.1972855638641037),
#  ('worked great', 0.19683261374544031),
#  ('problems though', 0.19610726792870697),
#  ('rather laptop', 0.1960291051785138),
#  ('great thing', 0.19466771573815386),
#  ('keyboard side', 0.19448560982700133),
#  ('keyboard excellent', 0.1939945911372353),
#  ('set old', 0.19355405963010813),
#  ('work expected', 0.19113446660667888),
#  ('market mini', 0.18990521355501619),
#  ('comes handy', 0.18885527305642749),
#  ('fast responsive', 0.18872310824461858),
#  ('reviews gave', 0.18738356311109217),
#  ('worked pretty', 0.18567050331304916),
#  ('systems annoying', 0.18502032200070223),
#  ('otherwise great', 0.18444871237175994),
#  ('really like', 0.18371702414131011),
#  ('lot battery', 0.18355883960339464),
#  ('yes use', 0.1827652046529325),
#  ('batteries included', 0.18027011307314),
#  ('shift key', 0.17996038131816716),
#  ('cheap feeling', 0.17858945727580447),
#  ('keyboard looks', 0.17761789645620646),
#  ('range listed', 0.17686589842258441),
#  ('would recommend', 0.17681547366283276),
#  ('waste time', 0.1757067915087567),
#  ('home office', 0.17524617992444694),
#  ('handy near', 0.17431501514785397),
#  ('iso keyboard', 0.17430809151979226),
#  ('layout little', 0.17345682976761112),
#  ('number pad', 0.17339974813998463),
#  ('well except', 0.17330777041204609),
#  ('keyboard use', 0.17285571576339623),
#  ('htpc usage', 0.17206163975996461),
#  ('touchpad input', 0.17109921142385565),
#  ('exactly supposed', 0.17063299382566841),
#  ('keyboard awkward', 0.17007012848516229),
#  ('recommend friend', 0.16831965530693846),
#  ('keyboard number', 0.16805736142052424),
#  ('recommend product', 0.16785725107955421),
#  ('one complaint', 0.16694590302171011),
#  ('get another', 0.16673186850612198),
#  ('send wong', 0.16671449838271701),
#  ('keyboard connected', 0.16508418016510371),
#  ('came days', 0.16504271193926448),
#  ('keyboard quite', 0.16414514731836868),
#  ('integrated touchpad', 0.16391170925469933),
#  ('open box', 0.16312577725017213),
#  ('keyboard bought', 0.16226016046687741),
#  ('enjoy keyboard', 0.16180226266417233),
#  ('keyboard awesome', 0.16171808023491419),
#  ('keyboard yup', 0.161302778009181),
#  ('great idea', 0.16128969663510992),
#  ('second portable', 0.16098444327199535),
#  ('could get', 0.16041161714656793),
#  ('great batteries', 0.15963629408198782),
#  ('return keyboard', 0.15601630513482048),
#  ('feel sturdy', 0.15575092217002451),
#  ('keyboard nice', 0.15555781792672635),
#  ('seems last', 0.1555314167345252),
#  ('got since', 0.15507530139566897),
#  ('keyboard exceeded', 0.15404167474600194),
#  ('try use', 0.15345923894678262),
#  ('wouldnt buy', 0.1523179948199351),
#  ('feel keys', 0.15194387994569958),
#  ('item arrived', 0.15136189133950234),
#  ('one point', 0.150767115800264),
#  ('keyboard almost', 0.14977009124003535),
#  ('one thing', 0.1489539648190922),
#  ('sorry keyboard', 0.14858720827812569),
#  ('purchased mac', 0.14830054086595454),
#  ('fullsized keyboard', 0.14826555933519187),
#  ('look elsewhere', 0.14821233936821854),
#  ('couple months', 0.14769217634791906),
#  ('pretty convenience', 0.14756468668141404),
#  ('needed foot', 0.14721572752007839),
#  ('keyboard way', 0.14666162473532618),
#  ('anywhere house', 0.14610858227433832),
#  ('barely typing', 0.14530504963632671),
#  ('keyboard super', 0.14459972979201199),
#  ('media searching', 0.14421792164313488),
#  ('plug broke', 0.1431286526554148),
#  ('small light', 0.14280322919360286),
#  ('really well', 0.14253170414568669),
#  ('perfect light', 0.14196222062106162),
#  ('happy purchase', 0.14132097922387088),
#  ('ordered keyboard', 0.14097508425763708),
#  ('job well', 0.14086403068400863),
#  ('keyboard pretty', 0.1403077984970072),
#  ('love light', 0.13935855565943125),
#  ('videos couch', 0.13913818515147802),
#  ('keyboard every', 0.13894657332846055),
#  ('fast easy', 0.13891419378144379),
#  ('something else', 0.13838588393152665),
#  ('biggest problem', 0.13835647744337309),
#  ('small keyboard', 0.13825403748533655),
#  ('year old', 0.13794995605263743),
#  ('another route', 0.13774748602012341),
#  ('amounts text', 0.13774256074455796),
#  ('overall good', 0.1369592792215239),
#  ('keyboardmouse combo', 0.1363151308986176),
#  ('really surprised', 0.13613345389866388),
#  ('creates problems', 0.13554350767226525),
#  ('keyboard good', 0.13544712943826717),
#  ('light hold', 0.13540664292247634),
#  ('quite say', 0.13505164745020254),
#  ('controlling computer', 0.13480256656422557),
#  ('solution fix', 0.13414848028040074),
#  ('computers keyboard', 0.13395256230232522),
#  ('like idea', 0.13373032388332221),
#  ('deserved stars', 0.13352922181221269),
#  ('keyboard setup', 0.13303418449087714),
#  ('good small', 0.13211503463772009),
#  ('makes working', 0.13208297579657041),
#  ('key area', 0.13180065569306482),
#  ('buy fast', 0.13176288234906183),
#  ('doesnt feel', 0.13114482297644034),
#  ('surprised see', 0.13109818473939719),
#  ('work freebsd', 0.12971338622648937),
#  ('sent back', 0.12963398364169815),
#  ('worked returning', 0.12921370851769798),
#  ('fairly well', 0.12907829448494626),
#  ('well purpose', 0.12882251260965905),
#  ('ive purchased', 0.1286218172039853),
#  ('taken kids', 0.1282439388740709),
#  ('begin thank', 0.12758998048495246),
#  ('light weight', 0.12756121438659795),
#  ('price however', 0.12737592822584018),
#  ('smaller footprint', 0.12731395790298244),
#  ('purchased bad', 0.12695422508147866),
#  ('pros installs', 0.1269419536580737),
#  ('cant get', 0.12676508417980084),
#  ('smaller size', 0.12656438423816163),
#  ('keyboard samsung', 0.12550575212365248),
#  ('except netflix', 0.12505055697707601),
#  ('keyboard expected', 0.1240590594397335),
#  ('things unnecessarily', 0.12390450845571593),
#  ('pros good', 0.12310779024925433),
#  ('words reviews', 0.12286354443165112),
#  ('feel flimsy', 0.12274414832635602),
#  ('amazon great', 0.12267451558599894),
#  ('without problem', 0.12236402987404026),
#  ('hooked lcd', 0.12217714369572574),
#  ('smaller features', 0.1221577832104037),
#  ('keyboard decent', 0.12128751976623497),
#  ('got product', 0.12069247673848529),
#  ('great range', 0.1206467595912),
#  ('love media', 0.12044698433703244),
#  ('could ask', 0.12010282281258365),
#  ('barely works', 0.12010081205058212),
#  ('perfect keyboard', 0.1195062272237728),
#  ('keyboard nothing', 0.11916043828023741),
#  ('exactly claims', 0.11907514341799406),
#  ('keyboard feels', 0.11904180407642767),
#  ('ive days', 0.11884054138898771),
#  ('moving screen', 0.1186680689827227),
#  ('somewhere middle', 0.11843162890414685),
#  ('best option', 0.11797244154360013),
#  ('good reason', 0.11711059223634181),
#  ('great buy', 0.11705138868743598),
#  ('range extender', 0.1169379176158709),
#  ('well gift', 0.11623599934020876),
#  ('one favorite', 0.11597666269526007),
#  ('got sale', 0.11575139762306381),
#  ('another brand', 0.11546079655175052),
#  ('demand refund', 0.1154246950510411),
#  ('bought replace', 0.11498614548831164),
#  ('windows keyboard', 0.11473130674785663),
#  ('house somewhere', 0.11442826963582313),
#  ('buying another', 0.1140687939644658),
#  ('computer recognized', 0.11376152974104128),
#  ('buy one', 0.11366535519031119),
#  ('would well', 0.11355797669760521),
#  ('price point', 0.11329337710835105),
#  ('everything else', 0.11307325572437134),
#  ('touchpad isnt', 0.11286384174153481),
#  ('separate mouse', 0.11254735993006339),
#  ('definitely get', 0.11229976450989891),
#  ('situations cheap', 0.11019097665026591),
#  ('good buy', 0.10991455075191624),
#  ('send email', 0.10957695222287021),
#  ('smooth light', 0.10956536738026032),
#  ('lightweight plastic', 0.10948300985736788),
#  ('annoying issue', 0.10920091049190163),
#  ('options mouse', 0.10901994779437908),
#  ('great first', 0.10858939309506634),
#  ('keyboard box', 0.10850594293069002),
#  ('item great', 0.10840416708276025),
#  ('doesnt anyone', 0.10724211012213859),
#  ('truly fantastic', 0.10724035793348677),
#  ('problems plugged', 0.10723374505689182),
#  ('computer well', 0.10696619250371485),
#  ('never worked', 0.10654635254440284),
#  ('instantly fast', 0.10646023368304659),
#  ('anything else', 0.10646019487333806),
#  ('batteries quickly', 0.10607590751896366),
#  ('disk plug', 0.10582617415066821),
#  ('would purchased', 0.10549181006365026),
#  ('shipped time', 0.1054443527486436),
#  ('keyboard slightly', 0.10533105051555852),
#  ('little cramped', 0.10494562103250826),
#  ('super light', 0.10478533622673691),
#  ('keyboard mini', 0.1045885680014617),
#  ('worry great', 0.10420704264778871),
#  ('bed anyway', 0.10401430844577124),
#  ('problem use', 0.10399426024440084),
#  ('keyboard back', 0.10398969251283136),
#  ('handy little', 0.10375814483857798),
#  ('looks great', 0.10347043332712445),
#  ('jungle already', 0.10342316011714914),
#  ('hate keyboard', 0.10325561798031982),
#  ('overall work', 0.10305134078843167),
#  ('workdo touch', 0.10286728263005124),
#  ('pros great', 0.10244314490095068),
#  ('worked much', 0.10242061996973748),
#  ('blew mind', 0.10204046244123524),
#  ('got teenager', 0.10194556502684451),
#  ('would order', 0.10192632807351083),
#  ('work portable', 0.10177480718947927),
#  ('returned item', 0.10167031962110928),
#  ('homerow kind', 0.10158882993248898),
#  ('pleased purchase', 0.10102214974186613),
#  ('cpu usage', 0.1006826176865899),
#  ('keyboard mediocre', 0.10040025702310641),
#  ('nexus tablet', 0.10014173009770772),
#  ('great fact', 0.10008250101047922),
#  ('decent price', 0.10008125862378733),
#  ('able make', 0.1000047539364964),
#  ('antenna seems', 0.099935577221772556),
#  ('layout requirements', 0.099377393025826127),
#  ('nice handy', 0.099362446391915493),
#  ('keyboard bad', 0.099264385399191621),
#  ('anyway go', 0.099245929277161582),
#  ('good product', 0.099146036027331658),
#  ('another pcs', 0.098943758881613025),
#  ('product arrived', 0.09886795970740847),
#  ('different keyboard', 0.098770535178452898),
#  ('alright keyboard', 0.09860874323335013),
#  ('yeah good', 0.098368250171626162),
#  ('old pc', 0.098068937634574929),
#  ('connection pc', 0.098005623984918896),
#  ('keyboard difficulty', 0.09777697022027565),
#  ('samsungs keyboard', 0.097608899694022352),
#  ('idea make', 0.097460783995382799),
#  ('functionally works', 0.097385751985314822),
#  ('decent small', 0.097226275919919655),
#  ('pleasantly surprised', 0.096840758351009262),
#  ('used cant', 0.09682162875844702),
#  ('knew bought', 0.096736855499182289),
#  ('wouldya think', 0.096585852873751904),
#  ('title says', 0.09657501637279288),
#  ('product anyone', 0.09643597151132198),
#  ('needs sleeve', 0.096285060055075158),
#  ('logitech wireless', 0.096252989105109849),
#  ('product quite', 0.096096598505325578),
#  ('feel natural', 0.095948590113292292),
#  ('control lap', 0.095907820538776417),
#  ('got keyboard', 0.095624975655454858),
#  ('mine one', 0.0956198118270674),
#  ('lg tv', 0.095498775135568106),
#  ('whoever decided', 0.095151420216244634),
#  ('keyboard needs', 0.095107750460938473),
#  ('better solution', 0.094910429701664231),
#  ('bought keyboard', 0.094804134358616829),
#  ('doesnt outdated', 0.094742315019219245),
#  ('builtin touchpad', 0.094572538473906786),
#  ('away laptop', 0.094569279258591377),
#  ('bought operating', 0.094469031002222981),
#  ('aware keyboard', 0.093809556259317861),
#  ('may havehttpyoutubeuzitxgvmtho', 0.093559730005302294),
#  ('worked situations', 0.093450051627246067),
#  ('didnt notice', 0.093333266951750371),
#  ('hours perfect', 0.093307744401241899),
#  ('complaint two', 0.093266041404387628),
#  ('great value', 0.093253237563294303),
#  ('usable keyboard', 0.093006248115720142),
#  ('also awesome', 0.092841630708966297),
#  ('cheap feel', 0.092841035977540579),
#  ('thought would', 0.092606686395080781),
#  ('keyboard otherwise', 0.09251314495973012),
#  ('overall love', 0.092395569952989601),
#  ('provided excellent', 0.092183441420618809),
#  ('samsung wireless', 0.091765005735987351),
#  ('return small', 0.091721511716161122),
#  ('put update', 0.091158671679440584),
#  ('mini keyboard', 0.091141933200727041),
#  ('works ok', 0.091104849036882207),
#  ('bought simple', 0.091076677752161592),
#  ('keyboard layout', 0.090926044115929403),
#  ('recommend great', 0.090543869699969887),
#  ('try hausbell', 0.089806100463036581),
#  ('needed something', 0.089706186068141),
#  ('think everyone', 0.089694235463963212),
#  ('layout small', 0.089466761831779679),
#  ('k keyboard', 0.089372554777311888),
#  ('operation keys', 0.089097883198929112),
#  ('unfortunately product', 0.089056323596022419),
#  ('keyboard well', 0.088879739260370863),
#  ('typing review', 0.088627088536023579),
#  ('away problems', 0.088507934251634418),
#  ('got thingy', 0.088359708261347966),
#  ('doesnt work', 0.088337967204838705),
#  ('user say', 0.088243648334047797),
#  ('keyboard allow', 0.087969596726320959),
#  ('long get', 0.087912128511073689),
#  ('great turned', 0.087626981060222903),
#  ('hooked laptop', 0.0873396386984676),
#  ('interferes typing', 0.087321605930171339),
#  ('perfectly far', 0.087254649696802661),
#  ('wireless range', 0.087216279706377714),
#  ('genius design', 0.08693991903135187),
#  ('ive gone', 0.086544147805614036),
#  ('reviews tips', 0.086456711725644592),
#  ('battery compartment', 0.086291706080378644),
#  ('handy device', 0.085971872554872958),
#  ('feel cheap', 0.085899395877624907),
#  ('office work', 0.085770177273596621),
#  ('excited buying', 0.08550074848818455),
#  ('small logitech', 0.085393632291363958),
#  ('touchpad irresponsive', 0.085268231051440532),
#  ('dont think', 0.085166679501119544),
#  ('im suffering', 0.084994688334087187),
#  ('bad choice', 0.084980972973150992),
#  ('didnt connect', 0.084686434270660457),
#  ('k lightweight', 0.084643649068787116),
#  ('touchpad weirdalthough', 0.084625125958578074),
#  ('lot less', 0.084378407606853528),
#  ('dont waste', 0.084293406785861932),
#  ('compact keyboard', 0.084212219861071469),
#  ('thing keeps', 0.08412813084199712),
#  ('big deal', 0.083829020012941388),
#  ('multitouch mousepad', 0.083582480630646258),
#  ('price right', 0.083023131078590579),
#  ('range bluetooth', 0.082010400863969227),
#  ('bad thing', 0.081689748802196135),
#  ('problem starts', 0.081684514098006186),
#  ('pad sensitive', 0.081378394088108486),
#  ('perfect purpose', 0.081117001520840004),
#  ('purposei liked', 0.080997985600048672),
#  ('make scroll', 0.080961650758790457),
#  ('love key', 0.080784002198419108),
#  ('tv thank', 0.080696909663720451),
#  ('watch movies', 0.080487758145020474),
#  ('keyboard suffers', 0.08031976220846497),
#  ('apple pc', 0.080182045309577038),
#  ('keyboard wall', 0.08012542422063812),
#  ('use mostly', 0.08004237796995145),
#  ('love recommend', 0.079421823820797599),
#  ('reading reviews', 0.079134961866180298),
#  ('completely useless', 0.079093927141866055),
#  ('fantastic keyboard', 0.079023604305367701),
#  ('first touch', 0.078581292578431827),
#  ('reason gave', 0.078440590783974626),
#  ('want click', 0.078421309858753993),
#  ('oh well', 0.078109603681149747),
#  ('works says', 0.078072931653067057),
#  ('keyboard started', 0.07806061048635056),
#  ('simple browsing', 0.078011191285038986),
#  ('mousewould recommend', 0.077702054462401846),
#  ('box perfect', 0.077666607863781462),
#  ('worth buying', 0.077426077500256277),
#  ('excellent price', 0.07735211644616817),
#  ('great use', 0.077120601951484902),
#  ('mouse around', 0.077072239544728263),
#  ('every penny', 0.077010727767840306),
#  ('wasnt needed', 0.076908789868854202),
#  ('bit cheap', 0.076657137609796047),
#  ('need wireless', 0.076652469911800886),
#  ('sometimes doesnt', 0.076347894433091645),
#  ('made light', 0.075763238146502945),
#  ('thing pretty', 0.075423748613753755),
#  ('exactly wanted', 0.074919990333651432),
#  ('little disappointed', 0.074864400105312562),
#  ('keyboard controlling', 0.07437624963564772),
#  ('bought samsung', 0.074292359454596016),
#  ('top left', 0.074224985864121087),
#  ('quality issues', 0.074103843871355615),
#  ('mostly love', 0.073943114070290944),
#  ('new netbook', 0.073513630369069383),
#  ('see better', 0.073304587234926874),
#  ('compact size', 0.072992366510318846),
#  ('tv case', 0.072826682110626123),
#  ('would expect', 0.072761453550320557),
#  ('good range', 0.072647594816628899),
#  ('hard navigate', 0.072632064268355362),
#  ('shipping went', 0.07262876303504856),
#  ('back track', 0.072581864468405546),
#  ('use first', 0.072488832068822479),
#  ('home computer', 0.072429384427351653),
#  ('allinone solution', 0.072214864165542805),
#  ('use keyboard', 0.072047217117011161),
#  ('deal one', 0.072008734173066732),
#  ('avoid product', 0.071945514784800782),
#  ('great except', 0.071857418069944029),
#  ('want refund', 0.071854251174627667),
#  ('would pay', 0.071772351113711053),
#  ('yep works', 0.071748396103952103),
#  ('much bigger', 0.071702538587677486),
#  ('perfect size', 0.071653975234936967),
#  ('use almost', 0.071653480959818161),
#  ('great work', 0.071469526770680469),
#  ('searched bluetooth', 0.070868460521908941),
#  ('bought wanted', 0.07075429660830862),
#  ('okay going', 0.07071517904500596),
#  ('touchpad instead', 0.070541831984521797),
#  ('touchpad convenient', 0.070402055074777606),
#  ('one came', 0.070147009430388263),
#  ('quality compromised', 0.070046170835771249),
#  ('like thank', 0.069966559684816784),
#  ('front television', 0.069872259383706975),
#  ('laptop tv', 0.06967225453791287),
#  ('tablet board', 0.069559901804386523),
#  ('waste money', 0.06952333204539482),
#  ('got monitors', 0.06948266127399759),
#  ('work windows', 0.06905278788924589),
#  ('excellent keyboard', 0.06891270521913076),
#  ('problem connection', 0.068834594124307383),
#  ('keyboard sole', 0.06819078982518402),
#  ('sensitivity accuracy', 0.068112826349089814),
#  ('prefer keyboards', 0.067947937618541288),
#  ('easy setup', 0.067417975003075697),
#  ('cant keyboard', 0.067331974948253936),
#  ('great pairs', 0.067246951311271591),
#  ('excited get', 0.066906257948070438),
#  ('ok light', 0.066701691191128384),
#  ('center setup', 0.066561709452979789),
#  ('simple durable', 0.066026554422090517),
#  ('would given', 0.065482244580728571),
#  ('though return', 0.065209261548236391),
#  ('performed fine', 0.06515082662814671),
#  ('logitech products', 0.065103048843139624),
#  ('behind tv', 0.064586757439201226),
#  ('though great', 0.064409029780303648),
#  ('keyboard inches', 0.064060143616026993),
#  ('bought fianceacute', 0.06395561598860372),
#  ('box tv', 0.063551269120796103),
#  ('well gbox', 0.063259456932184599),
#  ('keyboard synched', 0.062979293181524176),
#  ('instead annoying', 0.062834034031441929),
#  ('plug usb', 0.062537186164363587),
#  ('recommend anyone', 0.062338590997726824),
#  ('stars touch', 0.062208326914554642),
#  ('definitely recommend', 0.061814768875848955),
#  ('keyboard looked', 0.061798772208859952),
#  ('simple easy', 0.061792292182093485),
#  ('keyboard walmart', 0.061717249314340666),
#  ('keyboard android', 0.061607607508266334),
#  ('around click', 0.06135402143118826),
#  ('lg said', 0.061260019961257836),
#  ('traction typing', 0.061005866783241575),
#  ('kinda low', 0.060595415426150399),
#  ('wasnt looking', 0.060489818118323824),
#  ('keyboard ubuntu', 0.060433500604763532),
#  ('perfectly great', 0.060177781565655356),
#  ('one systeminnovative', 0.059934299433218624),
#  ('suggest anyone', 0.059836010840519559),
#  ('track pointer', 0.05980470052641499),
#  ('synched usb', 0.059802152519440759),
#  ('data remote', 0.05972240072285305),
#  ('fan logitech', 0.059708852740172354),
#  ('recently purchased', 0.059578310676051349),
#  ('clicking things', 0.059340841738346507),
#  ('happy returned', 0.059270109392485101),
#  ('feels cheaply', 0.059247645698275411),
#  ('browsefairly useless', 0.058709854445590362),
#  ('post begin', 0.058507537240846542),
#  ('degreei recommend', 0.058239790157086774),
#  ('logitech product', 0.058200773584276611),
#  ('never bought', 0.058118087804388908),
#  ('key problem', 0.058021781061643365),
#  ('service replace', 0.057919312260205476),
#  ('battery use', 0.05774648968103982),
#  ('keyboard switching', 0.057720534707062024),
#  ('worth price', 0.057683645508809792),
#  ('enter key', 0.057534434489210494),
#  ('bought friend', 0.057409920792044822),
#  ('dell laptop', 0.057383016507020511),
#  ('first keyboard', 0.057227904477517251),
#  ('average product', 0.057197172299921065),
#  ('feel cramped', 0.056965547303165769),
#  ('good productthough', 0.056837023247832352),
#  ('keyboard sitting', 0.056793593596858906),
#  ('better option', 0.05678739584570415),
#  ('mustve missed', 0.056613557122846568),
#  ('maddening try', 0.0565329474119192),
#  ('perfect pcs', 0.056293529159700331),
#  ('great truly', 0.056257603284824487),
#  ('needs little', 0.056050896654087565),
#  ('keyboard pc', 0.055866060858285098),
#  ('tv keyboard', 0.055839786100535568),
#  ('overall like', 0.055839364661797862),
#  ('os since', 0.0556727135997944),
#  ('besides work', 0.055583850628033775),
#  ('mouse key', 0.055578563223737026),
#  ('alternative anything', 0.055460037145812616),
#  ('hard make', 0.055364236421512072),
#  ('bed table', 0.055363909077446975),
#  ('tv great', 0.055201480278229742),
#  ('rest leg', 0.055150293556672586),
#  ('problems suits', 0.055141139463351869),
#  ('handy works', 0.054771671078692512),
#  ('rate five', 0.054522150662077745),
#  ('mk android', 0.053928274508368006),
#  ('works cheap', 0.053924841570775532),
#  ('mini wireless', 0.052983930294022992),
#  ('bought windows', 0.052844309330419552),
#  ('gave four', 0.052834851994815482),
#  ('mouse work', 0.052742461955249835),
#  ('smart tvs', 0.052698244126504548),
#  ('review months', 0.052549005342225417),
#  ('highly recommend', 0.052541906218076771),
#  ('little small', 0.052324826479298057),
#  ('keyboard hopes', 0.052163169261260134),
#  ('either hand', 0.052006764714725165),
#  ('control old', 0.051973168210777604),
#  ('hate keyboardif', 0.051883814819898483),
#  ('wish product', 0.051779926156414968),
#  ('different model', 0.051663095768301574),
#  ('poor construction', 0.051651473844213362),
#  ('use htpc', 0.051574801533195214),
#  ('overall great', 0.05151466591360853),
#  ('since wanted', 0.051332837013716145),
#  ('wanted laptop', 0.051301169895357712),
#  ('used old', 0.051298507850553746),
#  ('bought another', 0.050978072413597676),
#  ('hour using', 0.050906051908877648),
#  ('wasnt sensitive', 0.050842633942134945),
#  ('batteries months', 0.050779984105579198),
#  ('smartphones wanted', 0.050750152491502783),
#  ('keyboard wtouchpad', 0.050698298805967289),
#  ('bought smart', 0.050592664919373372),
#  ('always like', 0.050462791407695363),
#  ('product logitech', 0.050214179191078762),
#  ('cheap plastic', 0.050208164932718173),
#  ('keyboard seems', 0.050134661450760433),
#  ('best thing', 0.050082489632919718),
#  ('input device', 0.050049062178352227),
#  ('quite good', 0.04975681634615025),
#  ('writing code', 0.049736120507851943),
#  ('range feet', 0.049724052528637562),
#  ('easy operatehoping', 0.049638369831912492),
#  ('wanted light', 0.04935103150268489),
#  ('bought wifes', 0.049201696302001004),
#  ('keyboard within', 0.049190856085544167),
#  ('tapping feature', 0.049183572102615286),
#  ('ive different', 0.049087728993759946),
#  ('loving ease', 0.049051631767038917),
#  ('big definitely', 0.049049720001875505),
#  ('inside box', 0.049017951769346119),
#  ('love size', 0.048843579120267579),
#  ('use media', 0.048836702858292405),
#  ('going love', 0.048833281810044878),
#  ('know headline', 0.048769128926215544),
#  ('works okay', 0.048728319525804364),
#  ('useless include', 0.048654036729402286),
#  ('smaller laptop', 0.048650492132752375),
#  ('compact easy', 0.0485182789771543),
#  ('isnt responsive', 0.048517508124496463),
#  ('weighs nothing', 0.048277798359504048),
#  ('cannot recommend', 0.048254257533114853),
#  ('got work', 0.048139283405065708),
#  ('keyboard drive', 0.048063937272862692),
#  ('keyboard house', 0.047881941107503913),
#  ('arrow instead', 0.047782948126314277),
#  ('product little', 0.047740696264914326),
#  ('looking compact', 0.047693969372133396),
#  ('originally got', 0.047645947063490512),
#  ('ease use', 0.047294078498186433),
#  ('keyboard terrible', 0.047289170225074902),
#  ('buying willing', 0.047164666623686527),
#  ('like netbook', 0.047088749105669091),
#  ('house using', 0.046828947651918737),
#  ('give one', 0.046789383302481009),
#  ('decided put', 0.046556224907566821),
#  ('good find', 0.04632977681209359),
#  ('easy use', 0.046293867564577831),
#  ('great battery', 0.046257848181261448),
#  ('make function', 0.046029388700850271),
#  ('computer turn', 0.045938507443694501),
#  ('laptop connected', 0.045914443149487186),
#  ('idea practice', 0.04558744984306199),
#  ('mouse microsoft', 0.0455662504784623),
#  ('much lot', 0.045436251290970224),
#  ('keyboard thingy', 0.045296481201940068),
#  ('one use', 0.045243615930936398),
#  ('trouble brand', 0.045167439084431889),
#  ('incredibly frustrating', 0.045063104534124238),
#  ('clear problem', 0.044889505314557272),
#  ('curious whether', 0.044880450303968776),
#  ('another key', 0.04484453525509275),
#  ('underneath battery', 0.044831632282247354),
#  ('expected lightweight', 0.04456875988262031),
#  ('product work', 0.044456391018406323),
#  ('wheel though', 0.0443856851007398),
#  ('touch keyboard', 0.044313282318711539),
#  ('wish touchpad', 0.044305034966632476),
#  ('work panasonic', 0.044219066961932355),
#  ('still works', 0.043953422782649701),
#  ('keyboard fits', 0.043835991558791497),
#  ('operating smart', 0.043743254038665885),
#  ('keys responsive', 0.043734079426926066),
#  ('build quality', 0.043671814511849205),
#  ('pleased logitech', 0.043565759400874725),
#  ('changed batteries', 0.043344241021874917),
#  ('click arror', 0.043318601319437711),
#  ('keyboard size', 0.043266314631722882),
#  ('slim simple', 0.042995437339552606),
#  ('far pleased', 0.042949466127717863),
#  ('cant go', 0.042908197376856409),
#  ('okay supposed', 0.042806103723735195),
#  ('gave adequate', 0.042653745580314407),
#  ('ok product', 0.042548827775123026),
#  ('combo works', 0.042371003271195293),
#  ('give stars', 0.042114620668996822),
#  ('really say', 0.041839957952471793),
#  ('products usually', 0.041692487801122675),
#  ('pad scroll', 0.041286087930869714),
#  ('hook laptop', 0.041176575398678424),
#  ('clamshell mode', 0.041008055653580566),
#  ('doesnt make', 0.040996917088533036),
#  ('mousekeyboard separately', 0.040985633457798022),
#  ('laptop works', 0.04091347268370861),
#  ('fine track', 0.040732615687931982),
#  ('input little', 0.04055972151296542),
#  ('size weight', 0.040346290439187367),
#  ('deal againthanks', 0.040341420267625314),
#  ('lot wireless', 0.040272409731135946),
#  ('keypad selects', 0.040141118555078431),
#  ('would perfect', 0.040125878524191728),
#  ('purpose back', 0.039933753068446987),
#  ('intermittently loses', 0.039877652615899026),
#  ('useful touch', 0.039866521300448689),
#  ('using rikomagic', 0.039793348202874446),
#  ('ordered two', 0.039654496176089571),
#  ('use espesially', 0.039432014291617884),
#  ('enjoy using', 0.039368512621998288),
#  ('lightweight long', 0.039289399592955319),
#  ('add would', 0.039285904147395405),
#  ('two one', 0.039149193649729568),
#  ('keyboards yet', 0.039062176755990961),
#  ('terrible ive', 0.039012119648084563),
#  ('reviews carefully', 0.039010693734175358),
#  ('keyboard purpose', 0.038967525797726936),
#  ('laptop living', 0.038893520706372919),
#  ('flaw scroll', 0.038807449484724969),
#  ('works fine', 0.038736955556826699),
#  ('quite well', 0.03864910195161806),
#  ('whether keyboard', 0.038489255710653668),
#  ('reviews usually', 0.038474045654749225),
#  ('monitor batteries', 0.038422704591903271),
#  ('batteries demand', 0.038379522696716774),
#  ('everyday use', 0.038209786754716334),
#  ('ft system', 0.038038648736115711),
#  ('see help', 0.037909035724459937),
#  ('pretty well', 0.037523114546266861),
#  ('almost immediately', 0.037489388437054898),
#  ('serve purpose', 0.037318545177077618),
#  ('really stretching', 0.037265670324529883),
#  ('keyborad size', 0.037256687552286345),
#  ('works really', 0.037005352745325362),
#  ('well whats', 0.036935226703190667),
#  ('sight behind', 0.036854829895902871),
#  ('integrated keyboard', 0.036645314346548316),
#  ('use screen', 0.036637982458351911),
#  ('good feel', 0.036569625929841039),
#  ('anyone else', 0.036463624892524062),
#  ('comfortable lap', 0.036456520095174298),
#  ('received logitech', 0.036328528016060964),
#  ('excellent like', 0.035716594440454177),
#  ('really nice', 0.035704161416484616),
#  ('wanted small', 0.035335137915757861),
#  ('system return', 0.035316234400172869),
#  ('whats pint', 0.035309990763432796),
#  ('nothing special', 0.035205976538320333),
#  ('connection working', 0.035189110946962469),
#  ('bad price', 0.035051271186036917),
#  ('worked ok', 0.034875577979119485),
#  ('sensitiveness good', 0.034807904050675263),
#  ('pros lightweight', 0.034608988439265589),
#  ('imaged built', 0.034578416232915472),
#  ('even know', 0.034575928027258791),
#  ('near tv', 0.03450473975412871),
#  ('advertising waste', 0.034376977867206039),
#  ('bluetooth smartphones', 0.034258769181191619),
#  ('got g', 0.033934995872376653),
#  ('easy browse', 0.033911932845655905),
#  ('major quality', 0.033801452374608715),
#  ('delivery ease', 0.033551368577358243),
#  ('intelligence anyway', 0.033504105451333151),
#  ('plugnplay win', 0.033287556065823745),
#  ('half shift', 0.033156346112484816),
#  ('seems solidly', 0.033114386352876113),
#  ('wasted money', 0.03300562452552009),
#  ('although good', 0.032822196140488626),
#  ('know fussy', 0.032742127373451752),
#  ('two gifts', 0.032661372626462425),
#  ('rocks instantly', 0.032513123894412244),
#  ('feet awayperfect', 0.032509139613166267),
#  ('regular sized', 0.032479921400134296),
#  ('excellent versatility', 0.032446726465277187),
#  ('order seller', 0.032433988005234948),
#  ('use samsung', 0.032342417239467382),
#  ('likely returning', 0.032082454231295403),
#  ('looking good', 0.031695961377312246),
#  ('got htpc', 0.031531322049547214),
#  ('computers need', 0.031427100319135606),
#  ('love last', 0.03141538949756071),
#  ('x keyboard', 0.031350722414991192),
#  ('htpc house', 0.031307356000997183),
#  ('way works', 0.031284673167705834),
#  ('thats functional', 0.031194043960631187),
#  ('wanted nice', 0.031173510289315816),
#  ('documents etc', 0.030906856311899562),
#  ('flawlessly windows', 0.030883587869505801),
#  ('size compactness', 0.030826850859096009),
#  ('computer thank', 0.030723707077335093),
#  ('favor really', 0.03061642930769511),
#  ('good typing', 0.030577154999021913),
#  ('type facebook', 0.030433325942848279),
#  ('issue k', 0.030402230989302916),
#  ('connected tv', 0.030384497577363521),
#  ('update reviewboth', 0.030290562326998279),
#  ('use computer', 0.030283365910923243),
#  ('term use', 0.030213456454471366),
#  ('better ones', 0.029954453561239561),
#  ('product sent', 0.02994901603367436),
#  ('wireless mouse', 0.029936792788386454),
#  ('feedback small', 0.029931573353549332),
#  ('communicate smart', 0.029869715079630377),
#  ('quality product', 0.029844826109162895),
#  ('work spent', 0.029749505432610571),
#  ('ive brought', 0.029698090214338415),
#  ('referb happy', 0.029653276725566571),
#  ('pairing returning', 0.029515598493028053),
#  ('tried several', 0.029450925006139841),
#  ('pads tap', 0.029444386187149649),
#  ('keys backlight', 0.029410874534844325),
#  ('samsung smart', 0.028973856040342721),
#  ('small size', 0.028794570030365146),
#  ('im used', 0.028792909263165811),
#  ('using left', 0.02867884815581221),
#  ('pad easy', 0.028564421243537277),
#  ('busted return', 0.028473776897749683),
#  ('cable connect', 0.028461681955248681),
#  ('key working', 0.02844652981953702),
#  ('removed half', 0.028350417684118431),
#  ('started using', 0.02818426004999754),
#  ('using computers', 0.028131120828604503),
#  ('nice first', 0.028098856895535568),
#  ('wide screen', 0.027942208953253434),
#  ('turn problems', 0.027821931548109746),
#  ('cant type', 0.02769987318290856),
#  ('get keyboard', 0.027686895535528305),
#  ('room front', 0.027676279924434933),
#  ('small takes', 0.027524726362700935),
#  ('one day', 0.027235359187107906),
#  ('use tv', 0.027210296258044116),
#  ('use great', 0.027096903759509527),
#  ('thing agree', 0.026998908934232811),
#  ('wtouchpad pointer', 0.026998064406581004),
#  ('like way', 0.026991664325830007),
#  ('use laptop', 0.026976355624521119),
#  ('press hard', 0.026941314877918423),
#  ('first place', 0.026871776426113436),
#  ('typing papers', 0.026866440586605124),
#  ('home entertainment', 0.026823141828381931),
#  ('smaller keyboard', 0.026810565241562979),
#  ('happy working', 0.026751562858729271),
#  ('instead separate', 0.026655764358239773),
#  ('bluetooth keyboards', 0.026621049534184562),
#  ('complain worth', 0.026535600923537406),
#  ('chromebox connected', 0.026523446275532631),
#  ('movements tracked', 0.026512045592924038),
#  ('using unit', 0.026191018620875504),
#  ('good ft', 0.02594422534174521),
#  ('browser search', 0.025927777376348455),
#  ('table functions', 0.025673569411463724),
#  ('okay price', 0.025570424552158005),
#  ('use used', 0.025545318194982403),
#  ('widely available', 0.025292359517410191),
#  ('excited arrived', 0.025277658101788319),
#  ('glorified remote', 0.025259607785236102),
#  ('board samsung', 0.024979301009118108),
#  ('another one', 0.024900355483283305),
#  ('enough needs', 0.024860989397287685),
#  ('touchpad works', 0.024859612396955871),
#  ('price pay', 0.024624385700650571),
#  ('extra boost', 0.024590458094169321),
#  ('products time', 0.024527175417462677),
#  ('back try', 0.024031103871801067),
#  ('surface great', 0.024018273281445346),
#  ('went well', 0.023940761067762769),
#  ('sturdy logitech', 0.023922191129612424),
#  ('little quirky', 0.023807855916793404),
#  ('problem unit', 0.023743169416059619),
#  ('tv knew', 0.023669257513656613),
#  ('put price', 0.023585799802726088),
#  ('wonderful addition', 0.023457902262850615),
#  ('design team', 0.023388349523984293),
#  ('pressing key', 0.023345487875739195),
#  ('use chromebox', 0.022872471022295195),
#  ('litter power', 0.022747233806003936),
#  ('fine highly', 0.022667809488391581),
#  ('ueh smart', 0.022462893813548511),
#  ('well responsive', 0.022053045556029483),
#  ('install logitech', 0.022052534777740333),
#  ('use cpu', 0.021948888314831654),
#  ('perfect need', 0.021676720138365684),
#  ('keyboardtouchpad perfect', 0.021669702786226038),
#  ('still getting', 0.021612779186304675),
#  ('anyway fantastic', 0.021577621594934576),
#  ('changes yet', 0.021430081831824575),
#  ('dongle work', 0.021417591210201609),
#  ('needed cordless', 0.021364932862762188),
#  ('almost everyday', 0.021333929787958474),
#  ('pros small', 0.021274600290250613),
#  ('right shift', 0.021016371164287909),
#  ('reasonable price', 0.020947687584940877),
#  ('arent many', 0.020689229176971063),
#  ('terrible type', 0.020432756107613144),
#  ('day using', 0.02031893447688763),
#  ('money buy', 0.020134956909795457),
#  ('good job', 0.019928137311828992),
#  ('midnight gbox', 0.019692538870703505),
#  ('expect logitech', 0.019498209233995124),
#  ('week works', 0.01946751523394117),
#  ('see night', 0.019433256904309432),
#  ('key pretty', 0.019383262115713038),
#  ('media center', 0.018932658280261482),
#  ('make keyboard', 0.01862258732646983),
#  ('next annoying', 0.018575685426802553),
#  ('purchase back', 0.01857050212129556),
#  ('click select', 0.018560663001040416),
#  ('well didnt', 0.018366740997920704),
#  ('get pay', 0.017990912839694784),
#  ('like wireless', 0.017980694673060259),
#  ('big use', 0.017800063709214716),
#  ('size like', 0.017536238199721384),
#  ('good qualityheft', 0.01742160754248363),
#  ('sleeps pc', 0.017391920530808132),
#  ('gbox set', 0.01738770763919224),
#  ('wish plastic', 0.017326296029799459),
#  ('quality really', 0.017153942978513827),
#  ('windows media', 0.017098754221137456),
#  ('laptop amazed', 0.016807720748669756),
#  ('portable wires', 0.016747535117964979),
#  ('another product', 0.016452031381009133),
#  ('size logitech', 0.016150634992955742),
#  ('recommended purchase', 0.015991838303314403),
#  ('input part', 0.015744168272569876),
#  ('use remote', 0.015375021249573051),
#  ('often price', 0.015261275563377159),
#  ('market becoming', 0.014795104568477312),
#  ('works stated', 0.014323392258588712),
#  ('said rtfect', 0.014223228454029228),
#  ('hand side', 0.014060777799556423),
#  ('keyboard smaller', 0.013975584782636941),
#  ('feel stars', 0.013773102171984351),
#  ('saving battery', 0.013559206346593676),
#  ('using right', 0.012709382195282498),
#  ('wheel mouse', 0.012015199302414091),
#  ('home entertainement', 0.011839570084021693),
#  ('system would', 0.011736068346033175),
#  ('tv second', 0.01114955960160725),
#  ('phantom clicksrus', 0.0090341221061187478),
#  ('use daily', 0.008762850634107552),
#  ('slow cheep', 0.0078870328606187069),
#  ('looking forward', 0.0062507814917249199),
#  ('wong address', 0.0056860856121980392),
#  ('use totally', 0.0048591976467405665),
#  ('use may', 0.0042852446142585942)]

# %% [markdown]
# ## Pos / Neg Feature Extraction

# %% [markdown]
# #### 제품에 따라서, 긍/부정적인 요소가 뻔한 경우 확률 cutoff를 낮춰잡아야 다양한 요소 반영 가능

# %%
pos_features= {}
neg_features= {}
for feature in tqdm(list(features)):
    f_exist = product_review.loc[product_review['clean_text'].apply(lambda x : feature[0] in x)]
    prob = np.mean(f_exist['label'])
    if (prob >= 0.8) and (len(f_exist) > 2):
        pos_features[feature[0]] = feature[1]
    if (prob < 0.2) and (len(f_exist) > 2):
        neg_features[feature[0]] = feature[1]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 946/946 [00:00<00:00, 1377.69it/s]

# %%
sorted(pos_features.items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('works great', 2.3913055046529514),
#  ('purchased use', 0.45450569997386403),
#  ('great little', 0.4442857883459892),
#  ('highly recommended', 0.32024886614280818),
#  ('little keyboard', 0.29045903332282863),
#  ('works perfectly', 0.21108722789450485),
#  ('really like', 0.18371702414131011),
#  ('get another', 0.16673186850612198),
#  ('one thing', 0.1489539648190922),
#  ('keyboard setup', 0.13303418449087714),
#  ('well purpose', 0.12882251260965905),
#  ('light weight', 0.12756121438659795),
#  ('great range', 0.1206467595912),
#  ('great buy', 0.11705138868743598),
#  ('anything else', 0.10646019487333806),
#  ('big deal', 0.083829020012941388),
#  ('great use', 0.077120601951484902),
#  ('laptop tv', 0.06967225453791287),
#  ('plug usb', 0.062537186164363587),
#  ('definitely recommend', 0.061814768875848955),
#  ('highly recommend', 0.052541906218076771),
#  ('compact easy', 0.0485182789771543),
#  ('easy use', 0.046293867564577831),
#  ('laptop connected', 0.045914443149487186),
#  ('touch keyboard', 0.044313282318711539),
#  ('works really', 0.037005352745325362),
#  ('good feel', 0.036569625929841039),
#  ('use samsung', 0.032342417239467382),
#  ('use computer', 0.030283365910923243),
#  ('another one', 0.024900355483283305),
#  ('touchpad works', 0.024859612396955871),
#  ('windows media', 0.017098754221137456),
#  ('use daily', 0.008762850634107552)]

# %%
sorted(neg_features.items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('shift key', 0.17996038131816716),
#  ('waste time', 0.1757067915087567),
#  ('keyboard nice', 0.15555781792672635),
#  ('look elsewhere', 0.14821233936821854),
#  ('keyboard good', 0.13544712943826717),
#  ('sent back', 0.12963398364169815),
#  ('builtin touchpad', 0.094572538473906786),
#  ('works ok', 0.091104849036882207),
#  ('doesnt work', 0.088337967204838705),
#  ('waste money', 0.06952333204539482),
#  ('logitech products', 0.065103048843139624),
#  ('logitech product', 0.058200773584276611),
#  ('never bought', 0.058118087804388908),
#  ('enter key', 0.057534434489210494),
#  ('cheap plastic', 0.050208164932718173),
#  ('arrow instead', 0.047782948126314277),
#  ('product work', 0.044456391018406323),
#  ('im used', 0.028792909263165811),
#  ('cant type', 0.02769987318290856)]

# %% [markdown]
# ## Instance Pick

# %%
pos_reviews_explanations = list(product_review.loc[product_review['label'] == 1]['explanations'])
neg_reviews_explanations = list(product_review.loc[product_review['label'] == 0]['explanations'])
pos_chosen, _ = submodular_pick(pos_reviews_explanations, pos_features, k = 10, l_penalty=True)
neg_chosen, _ = submodular_pick(neg_reviews_explanations, neg_features, k = 10, l_penalty=True)

# %%
for review in pos_chosen:
    row = product_review.loc[product_review['clean_text'] == review[1]]
    text = row['reviewText'].iloc[0]
    label = row['label'].iloc[0]
    print(text,label,'\n')
# Out:
# I would have rated it a 5, but it doesn't have a number pad.  Otherwise it works great.  A side number pad will have to do. 1
#
# A great little keyboard/touchpad combo. After reading all the complaints about other keyboards with a built-in trackball that can't be cleaned, I went with the touchpad instead. Very happy with it. 1
#
# Love it. We have many Logitech keyboard/mice at work and no issues, so I am sure the quality is fine too. Highly recommended. 1
#
# Purchased to use with Samsung 3D Smart HDTV and it works great.  Was easy to setup and is a bigger improvement in moving around the screen to make choices with the Touch Pad.  Trying to use the remote with the TV to type in a website was very difficult and time consuming.  Now it's a breeze. 1
#
# I really like this wireless touch keyboard. It serves well my purpose. I will certainly recommend to my associates and friends. 1
#
# Compact but easy to use. Touchpad gives some of the same abilities for wiewing as smart phone screen. Can be used like a remote. 1
#
# works perfectly. I don't know what else I can say. I must say it is annoying that Amazon requires a certain number of words in their reviews. 1
#
# Light weight. Compact and easy to use. Work great on my Samsung TV. Nothing to complain about. Worth the money. 1
#
# Perfecting for lounging around on a couch or a bed. Tough little keyboard, I toss it aside without worry. Great buy. 1
#
# One thing that threw me off was the USB dongle it uses to connect to the TV is inside the unit when shipped. Snap off the battery cover to find it. It worked immediately on my LG TV. 1

# %%
for review in neg_chosen:
    row = product_review.loc[product_review['clean_text'] == review[1]]
    text = row['reviewText'].iloc[0]
    label = row['label'].iloc[0]
    print(text,label,'\n')
# Out:
# The lefthand shift key is in the right place, and note it's a double-sized key. Which it should be, considering how often you use it. The righthand shift key, however, is half this size, and to the right of the up arrow key. Many other compact keyboards have the Shift key to the left of the up arrow key, and pretty much all regular sized keyboards do as well. Before you purchase this keyboard, LOOK AT WHERE THE RIGHTHAND SHIFT KEY IS ON YOUR KEYBOARD, especially if you plan to alternate between keyboards, on different machines. 0
#
# It was not obvious to me from the advertising that this product only works with certain versions of Windows. Further, it comes with a tiny, tiny chip of some sort which either was not included or fell out while I was opening the package. Poor design, poor advertising. Waste of my time. 0
#
# This keyboard was nice for about the first day. It then started to cause Firefox to open new windows and tabs spontaneously, first with every 30-40 keystrokes, then in increasing frequency until it would no longer type, but pretty much only open Firefox tabs. Logitech support has been incredibly unhelpful and the retailer requires that you pay for shipping both ways and does not guarantee a full refund before you send the item back, but says it will assess it and determine what refund you get once it is received. That doesn't sound promising. I am very disappointed with this purchase, it's been a huge waste of time and money. 0
#
# .and for good reason. The right shift key has been move out of position to the right to make room for the up arrow. If you don't want to move the cursor up a line every time you go to type a capital letter, etc. look elsewhere. 0
#
# The keyboard itself it good. Never had problems with wireless connectivity.But the mouse I don't like. Most of the times I try to move pointer and it clicks. Sensitiveness is not good. 0
#
# In it's favor it is really inexpensive. But the reason is the cheap build quality.I don't know if it's because I was using this with a Mac and am used to things working smoothly but the cursor would stutter with the trackpad instead of moving perfectly smooth as it does with any Apple trackpad.  I sent it back. 0
#
# The range of Bluetooth is supposed to be around 25-30 feet, but I can't get this keyboard to connect unless it's within 3-4 feet of the receiver. If you're just sitting at desk, this isn't a problem, but I purchased this for the explicit use with my media center, which would require about 6 foot range. If you've got a media center or HTPC you're going to have to pony up about $50 more dollars and pick up the Logitech Wireless All-In-One Keyboard TK820 with Built-In Touchpad. 0
#
# Works OK. Light and easy to store. Not sure I can say much because I need to learn to use it better first. 0
#
# Does not work. spent an hr trying to get it installed on windows 7.DOES NOT WORK. REPEAT DOESN'T WORk. 0
#
# This is basically a useless piece of plastic.  Earlier today we used it to block the cat door, that's the most use it's been to us.  You can't use this with any of the apps on the Samsung Smart TV it is touted to work so well with.  If you're buying this to use with a TV- don't waste your money. 0

# %% [markdown]
# ## TextRank

# %%
pos_reviews = list(product_review.loc[product_review['label'] == 1]['clean_text'])
neg_reviews = list(product_review.loc[product_review['label'] == 0]['clean_text'])
reviews = pos_reviews + neg_reviews
tokens = [review.split() for review in reviews]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(sentence_tokens) for sentence_tokens in tokens]

# %%
ratio = 20 / len(reviews)
print(ratio)
# Out:
# 0.035842293906810034

# %%
textrank_summa_pos = summarization.summarize('. '.join(pos_reviews), ratio=ratio)
textrank_summa_neg = summarization.summarize('. '.join(neg_reviews), ratio=ratio)

# %%
for summa in textrank_summa_pos.split('.')[:-1]:
    row = product_review.loc[product_review['clean_text'] == summa.strip()]
    text = row['reviewText'].iloc[0]
    label = row['label'].iloc[0]
    print(text,label,'\n')
# Out:
# I use this on my Chromebox which I have connected to my TV, mainly to watch Hulu (I am not a Hulu+ subscriber).  The media and other special keys don't typically work well in that scenario, but otherwise this is a great single device to wirelessly have mouse and keyboard functionality.  The mouse movement lags just enough to be slightly annoying, but for my usage scenario it's far from a major complaint.  One thing that is very annoying though is the two-finger scroll gesture--it jumps from too slow to way too fast with little difference in how I'm moving my fingers between--it's very difficult to make it scroll a usable speed; this makes the gesture almost useless, which is sad because I use that gesture all the time on my Chromebook and have become very used to doing it. 1
#
# This little keyboard is great. I plugged the transponder in to my computer and boom it was ready to go I didn't even need to install any drivers but other customers might have a different experience, I bought this to hook up my computer to my home theater and it works like a charm. It is comfy and the touch pad is better than the one on my ultrabook very, responsive and precise. It is great to kick back on the couch and surf the web or watch videos on a service like Prime Instant and the alike. Five stars. 1
#
# I bought this keyboard to use with my computer that we hook up to our TV. I had to get a wireless keyboard with a mouse built in because my two year old was going to be using it and I didn't want to have him loose the mouse. I had read about how sometimes the built in mouse pads are not very receptive but this one is really good, I have never had problems with it. The size is perfect, it's not one of those small ones where you feel like you're using a phone this one actually feels like a keyboard and incredibly light. It does run on 2 AA batteries but it has a on/off button on the side which helps conserve a lot of battery. 1
#
# This is a wonderful addition to those of you who own a Smart TV, as well as folks who own a flat screen with HDMI connections. I have set up my Smart TV internet access using the wireless Logitech with built in keyboard, which makes web browsing easy from sitting on the sofa, recliner, etc. The price is competitive, and the quality of the unit is outstanding. I recommend this product for use with any PC, laptop and smart TV. 1
#
# We were looking for a good keyboard for a Samsung Smart TV and found this. It works great. We plugged the wireless USB stick in the side of the TV and it popped right up. All keys work as they should and the mouse pad allows you to move the cursor on the tv in all directions and angles, not just the X and Y axises (Up and Down, then Left and Right) like the remote. Great product, my TV is now my new netbook. 1
#
# I purchased this to use with my Samsung Smart HDTVSamsung UN40EH5300 40 Inch 1080p BlackI like it because it is easy to setup, slim and light weight, very responsive. It will work right out of the box and it comes with its on USB wireless toggle. It works great at a distance up to 12 feet and unlike blue tooth it has more range. Great keyboard for almost any device. I have also used it with my Dell laptop. 1
#
# This keyboard is just the right size for controlling my AV center pc running Ubuntu.  Being linux compatible out of the box is great.  I usually watch streaming TV shows and movies.  The keyboard setup is a little different but I love the built in mouse track pad.  I would not recommend it as a main keyboard for everyday pc use but it works perfectly as a AV center control keyboard for light web surfing or media searching. 1
#
# I think everyone buying this keyboard is using it for the same thing: as a glorified remote to control their media pc.  I've had mine for a couple of months now and it is working great.  It's nowhere near as large as a regular keyboard, but is big enough to type things in to Hulu, Netflix, etc. Additionally the built in touchpad puts this product well above similar models without one simply by eliminating the need for a wireless mouse.Would recommend. 1
#
# This product is great for use with a living room HTPC (Home Theater PC).  I have a laptop connected via HDMI to my big screen TV and this keyboard is perfect for light web browsing and controlling Netflix, Amazon Instant, and Itunes.  The touchpad is much better than other wireless touchpads that I have used and there is no problem using it from about 12 feet away on the couch. 1
#
# Used with both Win7 64-bit and WinXP 32-bit computers, fully functional out of the box without the need to install any drivers on either system (Volume/Mute, Home, and two-finger scroll all working fine).  Keyboard has an okay feel, wouldn't write a thesis on it but very usable for HTPC, keys have a good solid feel and keyboard feels well built.  Key layout is condensed, similar to that of a small laptop or netbook.  On/Off switch is nice for saving battery when not in use. 1

# %%
for summa in textrank_summa_neg.split('.')[:-1]:
    row = product_review.loc[product_review['clean_text'] == summa.strip()]
    text = row['reviewText'].iloc[0]
    label = row['label'].iloc[0]
    print(text,label,'\n')
# Out:
# I bought the black one, Its back was white which I love, its buttons are nice to press and dont make a lot of sound.mousepad is good and easy to use. I like that the F1-F12 are pressed with the Fn button and the volume and playback keys are put in front. in spite of that the Alt+F4 combination is still there and you dont need to use the Fn to get it.A big disadvantage is that the right shift is so small and put behind the up/pageup button, that annoys me alot (hence -2 stars)  because each time I press the shift key while typing I end up pressing the up button, this happened to me while writing this alot.Oh, it has no umber lock, so bye bye special characters (Alt+number) like &#9786; ( I used my old keyboard for that) 0
#
# I was excited about buying a keyboard with a touchpad so I could ditch my wireless mouse, however, I do a lot of actual office work with it, and it drives me absolutely CRAZY that the right shift key is not full size. It's the size of  a number key and it's too far over to the right. Maybe this isn't a big deal if you have very large hands, however, I end up hitting up arrow instead of shift, especially when trying to type and capitalize things it is super annoying to be returned to the beginning of whatever I'm typing. (Literally this happened twixe just during typing this review) 0
#
# Do not buy this if you are a fast typist. If you are of the hunt-and-peck ilk, it probably won't matter, but fast typists will be seriously hampered by the size of the right pinky shift key.  Your pinky reaches for it, and you always end up hitting the enter button or an arrow key (can't remember because I sent it back) or some key that is poorly placed.  The track pad is kind of neat but it will take getting used to, if you've used nothing but mice. Logitech knows mice (I do have a small USB mouse that works on all my devices, but this keyboard: nothing doing. 0
#
# This keyboard/mouse combo works well considering the very inexpensive price.  However, anyone who touch types fast will hate it because some of the keys are not in standard places and the entire keyboard seems undersized. As examples, the right shift key is NOT next to the question mark key, and end, home, page up, and page down are embedded functions vs. dedicated keys.  This keyboard might be good for occassionally entering info but it is very frustrating to use on a regular basis for rapid entry of text or numbers. 0
#
# I had high hopes for this product considering the great reviews it had. However I was disappointed:1. The keyboard (I got the white version) looks awfully cheap and plasticky2. The keyboard makes too much noise when its types, its not very quiet at all3. I'm used to a nice Apple trackpad, so this trackpad was really dissatisfying- the trackpad was small, not very responsiveI don't really recommend this keyboard, I'm going to be returning this and purchasing a regular separate wireless keyboard and mouse instead. 0
#
# Pros:- Small- Lightweight- Works with Logitech universal receiverCons:- Flimsy- Up arrow key where right shift key should be (deal breaker)- Not well balanced- Keys have poor feelBottom line: If you need something like this (instead of feeling it would be superior to what you have) then this likely a very good choice. For most people, a sturdier keyboard that has normal keys will work better (and if you can use a normal mouse or trackpad, even better to have a normal keyboard).If you want to use this on a Mac, read the higher-rated Mac-specific reviews for tips. 0
#
# Very dissapointed despite reading the reviews that this product promises. My Samsung UN46F6300 smart tv could tell that it was a Logitech keyboard connected, however the keyboard simply does not work and neither it's tracking pad. It feels light and cheap like as if it is just a model instea of an actual functioning device. I've tried switching out multiple batteries. I demand a refund. 0
#
# Multitouch mousepad works great and no connectivity problems.  The only major complaint that I have is that the arrow keys are right underneath the shift button on the right hand side. Since this is the shift key I use most often more often than not I inadvertently hit the arrow key and it sends the cursor off.  I suppose if I used this keyboard exclusively I'd get used to it but I bought to be used for typing occasionally or when the computer is hooked up to tv.  Other than the keyboard it's a great product but given the amount of typing for school I've done with it so far this was a big design flaw in my opinion. 0
#
# Great idea, but in practice it's so light that its hard to keep still on your lap and properly press keys, and the left/right mouse click buttons.  And the proprietary USB dongle is very easy to lose if you're moving from one machine to another.On the positive, it just worked with every pc, mac and chromebox, linux box I tested it on.I wouldn't recommend to a friend.  I replaced this with a Logitech K810 (bluetooth with 3 dedicated device configured buttons to easily switch to 3). 0
#
# I just received the Logitech Wireless Touch Keyboard K400 with Built-In Multi-Touch Touchpad and have used it for about an hour.Pros: remarkably good packaging, easy installation, batteries included, touchpad works greatCon: it is not standard keyboard size. Perhaps I missed this in the product description, but the entire keyboard with touchpad is about five inches shorter than the keyboard I was previously using. The shift key is quite small (the size of the arrow button located just below it) so many typos, mistakes, and wrong lines have been my initial experience with actually using the keyboard. 0
