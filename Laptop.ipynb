# %% [markdown]
# ## Data Loading

# %%
from data_handler import *
from submodular_pick import *
import random
import numpy as np
import nltk
import re
from sklearn.pipeline import make_pipeline
from gensim.models import Doc2Vec
from gensim import corpora
from gensim.models.doc2vec import LabeledSentence
from gensim import summarization
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import accuracy_score
from lime.lime_text import LimeTextExplainer
import operator
from tqdm import tqdm

# %%
reviewData_filepath = 'reviews_Electronics.json'
metaData_filepath = 'meta_Electronics.json'
metadata_df = load_metadata(metaData_filepath)
# Out:
# # Exception occured : 40

# %%
category_counts = metadata_df['categories'].value_counts()

# %%
product_group_name = 'Electronics, Computers & Accessories, Laptops'

# %%
product_group_review_data = get_reviewdata_of_product_group(product_group_name, metadata_df, reviewData_filepath)
product_group_review_data['label'] = product_group_review_data['overall'].apply(lambda x : 1 if x >= 4 else 0)

# %%
product_id = 'B009LL9VDG'

# %%
product_review = product_group_review_data.loc[product_group_review_data['asin'] == product_id]

# %%
def clean_punctuation(text):
    text = re.sub('\\!+', '.',text)
    text = re.sub('\\?+', '.',text)
    text = re.sub('\\.+','.',text)
    return text

# %%
product_review = product_group_review_data.loc[product_group_review_data['asin'] == product_id]

product_review['reviewText'] = product_review['reviewText'].apply(lambda x : clean_punctuation(x))

product_review = product_review.loc[product_review['reviewText'].apply(lambda x : len(x.split('.'))>=4)]
product_review = product_review.loc[product_review['reviewText'].apply(lambda x : len(x.split('.'))<=6)]
num_pos = len(product_review.loc[product_review['label'] == 1])
num_neg = len(product_review.loc[product_review['label'] == 0])
resampled_pos = product_review.loc[product_review['label'] == 1].iloc[random.sample(range(0,num_pos),num_neg)].reset_index(drop=True)
product_review = resampled_pos.append(product_review.loc[product_review['label'] == 0]).reset_index(drop=True)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
len(product_review)
# Out:
# 780

# %% [markdown]
# ## Embedding

# %%
def clean_text(text):
    text = text.strip()
    text = text.lower()
    text = re.sub('[^a-z ]', '', text)
    text = re.sub(' +', ' ', text)
    text = ' '.join([word for word in text.split() if word not in stoplist])
    return text

# %%
class Custom_pipeline:
    
    def __init__(self, embedder, predictor):
        self.embedder = embedder
        self.predictor = predictor
        
    def predict_proba(self, x):
        embedded_x = [self.embedder.infer_vector(i.split()) for i in x]
        return self.predictor.predict_proba(embedded_x)
    
    def fit(x,y):
        self.predictor.fit(x,y)

# %%
stoplist = set(nltk.corpus.stopwords.words('english'))

product_review['clean_text'] = product_review['reviewText'].apply(lambda x : clean_text(x))

instances = []
for i in range(len(product_review)):
    instance = LabeledSentence(words=product_review.loc[i,'clean_text'].split(), tags=[str(i)])
    instances.append(instance)

# %%
# for size in [30,50,70,100,200,300,400,500,700]:
    
#     for window in [6,8,10,12,14]:

#         model = Doc2Vec(size = size, window = window, workers = 3)
#         model.build_vocab(instances)
#         for epoch in range(20):
#             random.shuffle(instances)
#             model.train(instances)
#         embedded_text = [model.docvecs[str(x)] for x in range(len(product_review))]

#         clf = LogisticRegression(penalty='l1')
#         scores = cross_val_score(clf, embedded_text, product_review['label'], cv=10)
#         print(size,window,epoch,np.mean(scores))

# %%
best_vec_size = 50
best_window_size = 14

model = Doc2Vec(size = best_vec_size, window = best_window_size, workers=10)
model.build_vocab(instances)

for epoch in range(20):
    random.shuffle(instances)
    model.train(instances)
    
embedded_text = [model.docvecs[str(x)] for x in range(len(product_review))]

clf = LogisticRegression(penalty='l1')
scores = cross_val_score(clf, embedded_text, product_review['label'], cv=3)
print(np.mean(scores))

clf.fit(embedded_text, product_review['label'])
p_comp = Custom_pipeline(embedder = model, predictor = clf)
# Out:
# 0.741025641026

# %%
model.most_similar('good')
# Out:
# [('excellent', 0.42109382152557373),
#  ('great', 0.412241131067276),
#  ('perfectly', 0.4026727080345154),
#  ('way', 0.40017855167388916),
#  ('nice', 0.3994280695915222),
#  ('sound', 0.3843111991882324),
#  ('kind', 0.3583163619041443),
#  ('functional', 0.3424456715583801),
#  ('stream', 0.34095680713653564),
#  ('gaming', 0.32450658082962036)]

# %% [markdown]
# ## LIME

# %%
class_names = ['negative', 'positive']
explainer = LimeTextExplainer(class_names = class_names)

# %%
% time product_review['explanations'] = product_review['clean_text'].map(lambda x : get_explanation(explainer=explainer,\
                                                                    pipeline = p_comp, instance = x))
# Out:
# Wall time: 1min 7s

# %%
feature_importances = get_feature_importances(list(product_review['explanations']))
features = sorted(feature_importances.items(), key=operator.itemgetter(1), reverse=True)

# %%
features
# Out:
# [('get pay', 1.0282845110228394),
#  ('samsung chromebook', 0.98617679714108974),
#  ('light weight', 0.95102829015860557),
#  ('great product', 0.91740637979659501),
#  ('highly recommend', 0.87898669162667864),
#  ('great computer', 0.8046045002811375),
#  ('nice little', 0.71318965507677845),
#  ('little laptop', 0.66976043969992993),
#  ('cant beat', 0.54422319491550597),
#  ('read reviews', 0.54397485837575665),
#  ('battery life', 0.51861198204402159),
#  ('definitely recommend', 0.50647388151164352),
#  ('little disappointed', 0.49653782160153287),
#  ('love samsung', 0.47555381398482749),
#  ('return policy', 0.45630384165718674),
#  ('stay away', 0.45089493621882681),
#  ('everything else', 0.44729040406685666),
#  ('product definitely', 0.44180975678626655),
#  ('child could', 0.4235000328438161),
#  ('product exactly', 0.41023354078877688),
#  ('piece equipment', 0.40938974865942668),
#  ('sent back', 0.40249849049544523),
#  ('exactly wantedit', 0.39889158425393928),
#  ('flimsy returned', 0.39018340122441214),
#  ('disappointed chromebook', 0.3897459652285995),
#  ('want returned', 0.38881726064834299),
#  ('little computer', 0.38755039203963332),
#  ('little notebook', 0.38133745591652696),
#  ('price cant', 0.38066664218957519),
#  ('perfect product', 0.37757204100165165),
#  ('lap top', 0.37639148744584217),
#  ('product meets', 0.37395868265521037),
#  ('little machine', 0.37263479292301532),
#  ('cant think', 0.36986685681690729),
#  ('ended returning', 0.3663350291530123),
#  ('quality item', 0.35585427002825393),
#  ('screen size', 0.35273865635648466),
#  ('guess one', 0.35001198213143248),
#  ('love chromebook', 0.34315464599151851),
#  ('item purchased', 0.34045162361906967),
#  ('tried avi', 0.33606947112412905),
#  ('device could', 0.32440885739525521),
#  ('showing covered', 0.32251515681213372),
#  ('chrome book', 0.32135567718440666),
#  ('facebook games', 0.31935062942721171),
#  ('bucks one', 0.31883422444752552),
#  ('real laptop', 0.31767334136549552),
#  ('thing terrible', 0.31730755189499521),
#  ('piece krapp', 0.31698007077279938),
#  ('windows os', 0.3162212183440849),
#  ('chromebook came', 0.3136053964356954),
#  ('last months', 0.31323392400128153),
#  ('nice laptop', 0.3079390922038614),
#  ('click link', 0.30757884379769324),
#  ('item great', 0.30750218139442026),
#  ('happy samsung', 0.30691904290979477),
#  ('youre already', 0.30525078359781121),
#  ('equivalent laptops', 0.30096415345415861),
#  ('windows love', 0.30042456058321931),
#  ('recommend others', 0.29990853245988225),
#  ('cant live', 0.29504654960118359),
#  ('looks nice', 0.29124488118961417),
#  ('great price', 0.28988444390130719),
#  ('great machine', 0.28919535335538654),
#  ('trying charge', 0.28882654552556003),
#  ('dont want', 0.28814633830916364),
#  ('super disappointed', 0.28780990127562533),
#  ('happy buy', 0.28725050489976023),
#  ('reader java', 0.28719679121162373),
#  ('want return', 0.28405213116378814),
#  ('product advertised', 0.28263006927396345),
#  ('could get', 0.28244819526048348),
#  ('cost much', 0.28198313455430563),
#  ('several pros', 0.27960810755060744),
#  ('lightweight fast', 0.2782414208656207),
#  ('would recommend', 0.27747208927557515),
#  ('screen cracks', 0.27713621564956048),
#  ('mind said', 0.27673484910256385),
#  ('got item', 0.27546668929565926),
#  ('pleased product', 0.27026235700038242),
#  ('little longer', 0.27002771327930275),
#  ('exactly review', 0.26972177387727952),
#  ('future laptops', 0.26839876999060924),
#  ('super impressed', 0.26819710180646023),
#  ('pc runs', 0.26790094222413308),
#  ('fast reliable', 0.26742313336653323),
#  ('much happier', 0.26694749331230966),
#  ('google chrome', 0.26586264155325678),
#  ('price right', 0.26576472043452942),
#  ('husband isnt', 0.26418023047554545),
#  ('back replacement', 0.26113040700166557),
#  ('ordered mom', 0.26092234165799605),
#  ('laptop everything', 0.25902268695734365),
#  ('best laptop', 0.25844690327374537),
#  ('great little', 0.25819498963119836),
#  ('everything expected', 0.25774406051358661),
#  ('works ok', 0.25750164486706356),
#  ('please notebookthis', 0.25711215421824601),
#  ('sleek ways', 0.25657395553172968),
#  ('fire hd', 0.25595959412708086),
#  ('months chromebook', 0.25568848336616373),
#  ('missing os', 0.2546273897397951),
#  ('reviews college', 0.25429846251846128),
#  ('love little', 0.25376303973669823),
#  ('said new', 0.25203272542684108),
#  ('instructions told', 0.25125743956238805),
#  ('screen great', 0.25071972547798238),
#  ('lightweight compact', 0.24962186072143275),
#  ('information others', 0.249040164498918),
#  ('perfect traveling', 0.24836365491515777),
#  ('screen death', 0.24795566707700686),
#  ('shipped back', 0.24791524625182265),
#  ('part guess', 0.24779619690237031),
#  ('fast efficient', 0.24696321462542439),
#  ('traveling companions', 0.24660919092551956),
#  ('still though', 0.24656122333391711),
#  ('months minimal', 0.24579654252604277),
#  ('cannot believe', 0.24379018878563652),
#  ('thing awesome', 0.24312620452974373),
#  ('got chromebook', 0.24263048810699464),
#  ('someone please', 0.24026270395657406),
#  ('ipad flashplayer', 0.23951360348629305),
#  ('itunes disappointed', 0.2377246740712369),
#  ('quite techie', 0.2366981882834058),
#  ('new one', 0.23656262064981723),
#  ('took quite', 0.23452627793143702),
#  ('one star', 0.2343302126188293),
#  ('present husband', 0.23424923843292361),
#  ('touch screen', 0.23161926903351163),
#  ('love thing', 0.23100965241563437),
#  ('include returned', 0.22895468555025467),
#  ('phone clear', 0.22867709164403674),
#  ('works alright', 0.22788497892072662),
#  ('longer months', 0.22693761107835714),
#  ('exe files', 0.22581440591300858),
#  ('love watch', 0.22494691026035435),
#  ('product fell', 0.22486217337362097),
#  ('cloud storage', 0.223922493382086),
#  ('ever owned', 0.22380374151803906),
#  ('could go', 0.22347032557101118),
#  ('need time', 0.22306839989582336),
#  ('purchasing item', 0.22259859227265241),
#  ('dollars spent', 0.2212763159407346),
#  ('laptops work', 0.22114048329817562),
#  ('sorry cant', 0.22107842753427484),
#  ('start fast', 0.22060059746027358),
#  ('horrible experience', 0.22059774677537763),
#  ('social sites', 0.22017188844516411),
#  ('bought chromebook', 0.21964656743214964),
#  ('work play', 0.21955526653039881),
#  ('simple product', 0.21864985909643994),
#  ('love chrome', 0.2181894176402894),
#  ('social networking', 0.21763786544660388),
#  ('life awesome', 0.21633864812024658),
#  ('works online', 0.21596140449562684),
#  ('chance use', 0.2158473862412503),
#  ('great chromebook', 0.21476505863197598),
#  ('item initially', 0.21455868148360105),
#  ('higher work', 0.21339328926937462),
#  ('love fast', 0.21311560442005906),
#  ('love big', 0.2120049342249129),
#  ('might perfect', 0.2119737062351672),
#  ('want know', 0.21178647997342179),
#  ('many compliments', 0.2115679394716472),
#  ('samsung best', 0.2110806285928104),
#  ('run flash', 0.20886037006400207),
#  ('best choice', 0.20814728115659673),
#  ('exactly described', 0.20681371418954902),
#  ('impressed item', 0.20660745271554282),
#  ('lifewell done', 0.20536082004662903),
#  ('product certainly', 0.20525691611063648),
#  ('wifi perfect', 0.205193680704014),
#  ('damaged product', 0.20488454573452225),
#  ('two weeks', 0.20407431004450807),
#  ('storage enough', 0.20373945581169847),
#  ('laptop work', 0.20323240465426945),
#  ('everything greatexceptional', 0.20307918206874045),
#  ('love new', 0.20148549324820075),
#  ('software works', 0.20120670501078849),
#  ('chromebook several', 0.20116679492704825),
#  ('keyboard wonderful', 0.20020818144742561),
#  ('first thought', 0.19999070761032223),
#  ('much online', 0.1999257122660929),
#  ('recommend highly', 0.19932669359681895),
#  ('needed laptop', 0.19913611066881279),
#  ('away samsung', 0.19842010144860234),
#  ('connection forget', 0.19786446831564886),
#  ('internet connection', 0.19701883558495237),
#  ('really high', 0.19655325587298836),
#  ('great months', 0.19625311073324642),
#  ('received laptop', 0.1962210506319769),
#  ('trying resolve', 0.19607100289289719),
#  ('facebookbook netbook', 0.19529534749427674),
#  ('chromebook great', 0.19484945476175652),
#  ('touchpad great', 0.19478060118579629),
#  ('online applications', 0.19441177379488569),
#  ('product best', 0.1941848179602271),
#  ('good advertised', 0.19339858479126107),
#  ('trying find', 0.19335696023305085),
#  ('way run', 0.19299445280383676),
#  ('kinda cool', 0.1925691383248353),
#  ('everything use', 0.1922975656133758),
#  ('nice display', 0.19158192916931518),
#  ('doesnt work', 0.19138926842503767),
#  ('product price', 0.19117672780327727),
#  ('still works', 0.19089172167742707),
#  ('way back', 0.19079025803373734),
#  ('mins satisfied', 0.19070434597397382),
#  ('soninlaw one', 0.18979533118190126),
#  ('unfortunately chromebook', 0.18944725158355524),
#  ('quite wonderful', 0.18894987175724159),
#  ('plus much', 0.18876508599900388),
#  ('love relieved', 0.18866088544755283),
#  ('google youtube', 0.18858127879566045),
#  ('months usbs', 0.18815389437620567),
#  ('price one', 0.18764283580949612),
#  ('chromebooks future', 0.18623718640695411),
#  ('husband heard', 0.18531019635631682),
#  ('virus protection', 0.18502092926422634),
#  ('whatever thought', 0.1846953867924816),
#  ('ok quite', 0.18423230555264483),
#  ('computer runs', 0.18414857033233373),
#  ('stable device', 0.18351155202263572),
#  ('little chromebook', 0.18336612115296402),
#  ('fantastic everything', 0.1813877877184033),
#  ('maybe great', 0.18121171309186124),
#  ('wifi isnt', 0.18029807029947062),
#  ('learning curve', 0.17972450935877513),
#  ('netbook capability', 0.17942880547055057),
#  ('put skype', 0.17930667037506795),
#  ('didnt need', 0.17877791236904667),
#  ('blue screen', 0.17852314052798637),
#  ('design like', 0.17840893318709619),
#  ('money beat', 0.17798248303747807),
#  ('bought second', 0.17782876437239251),
#  ('screen small', 0.1776437710403759),
#  ('simply best', 0.17752007322124258),
#  ('like told', 0.17685479054817957),
#  ('quality product', 0.17651254192688387),
#  ('travel worth', 0.17616170950704707),
#  ('got new', 0.17586206436856744),
#  ('also recommend', 0.17573056092857928),
#  ('thing fast', 0.17546682568576888),
#  ('like reviews', 0.17505938612625155),
#  ('cant os', 0.1748636614856737),
#  ('couldnt connect', 0.1747905141431475),
#  ('hp printers', 0.17474283714536828),
#  ('forthcoming day', 0.17440874523309124),
#  ('works greatw', 0.17372228856507529),
#  ('ive used', 0.17359827025725019),
#  ('nice well', 0.17337408220629882),
#  ('one crazy', 0.17305251442082559),
#  ('cant go', 0.17287052029961655),
#  ('didnt really', 0.17225583989617083),
#  ('pros lightweight', 0.17214315561523041),
#  ('given majority', 0.17196771850539866),
#  ('many frustrating', 0.171555539089428),
#  ('work returned', 0.17138693779380615),
#  ('easy use', 0.17120024824403274),
#  ('flat faster', 0.17050636949056153),
#  ('weeks ormore', 0.17045273826243751),
#  ('didnt perks', 0.169995984870741),
#  ('use love', 0.16944056413880537),
#  ('wife homework', 0.16906663332563987),
#  ('perfect fit', 0.16867900206311981),
#  ('something else', 0.16856893383462945),
#  ('thought would', 0.16843233096711244),
#  ('without internet', 0.16805414088108059),
#  ('highly recommended', 0.16803009003653685),
#  ('closer screen', 0.16801480159860893),
#  ('printer order', 0.16796162633977538),
#  ('chromebook nice', 0.16704964238371436),
#  ('sleek fast', 0.16679241552433444),
#  ('recieved chromebook', 0.1665374489330122),
#  ('travel computer', 0.16644084910864224),
#  ('stay sick', 0.16620492126441133),
#  ('love spent', 0.16610411870593902),
#  ('sending back', 0.16608176029626806),
#  ('need roouter', 0.16598429230865702),
#  ('faster easier', 0.16559553919312259),
#  ('doesnt destroy', 0.16549175159227206),
#  ('machine purchased', 0.16544184973667397),
#  ('daughters laptop', 0.16479213758711886),
#  ('good hangout', 0.16470666914425855),
#  ('installed devices', 0.16415869617796131),
#  ('whole purpose', 0.16397189992543149),
#  ('excellent little', 0.16395397803510972),
#  ('like google', 0.16364593679253042),
#  ('satisfied performancethank', 0.16361293637554467),
#  ('machine great', 0.16334344990739935),
#  ('wont able', 0.16301563915849485),
#  ('though skeptical', 0.16253146077812461),
#  ('computer great', 0.16249447775491588),
#  ('failedchinese garbage', 0.1620945586622892),
#  ('disappointed purchase', 0.16204879839191325),
#  ('tech need', 0.16184106118019279),
#  ('definitely laptop', 0.1618020749243145),
#  ('android os', 0.16134242440554283),
#  ('less bucks', 0.16105446170784124),
#  ('dont know', 0.16082040475811629),
#  ('java upfront', 0.16071691936789614),
#  ('camera thats', 0.16051820620183818),
#  ('absolutely problems', 0.16051788059745051),
#  ('totally love', 0.15966514661835005),
#  ('exactly needed', 0.15966119957991984),
#  ('order buy', 0.15960460435838042),
#  ('dissapointing product', 0.15959401839503784),
#  ('nice addition', 0.15930389998182215),
#  ('ive selling', 0.15900319349074246),
#  ('money back', 0.15866125592581604),
#  ('great bang', 0.15828168795594713),
#  ('printer home', 0.15828140736665602),
#  ('reajusting screen', 0.15779799470701139),
#  ('product nothing', 0.15773245831529081),
#  ('like pc', 0.1573580994644462),
#  ('second laptop', 0.157038714108095),
#  ('weeks get', 0.15675654574759218),
#  ('affordable yr', 0.15653115900732426),
#  ('cool product', 0.15605914292753523),
#  ('many things', 0.15601189929583448),
#  ('great typing', 0.15578089111570376),
#  ('spent sometime', 0.15565976635117468),
#  ('poor wifi', 0.15550411014307439),
#  ('many apps', 0.15540126708463206),
#  ('chromebook screen', 0.1552629034286078),
#  ('really wished', 0.15524580066835128),
#  ('thought computer', 0.15505708677461549),
#  ('perfect choice', 0.15484072446460539),
#  ('word powerpoint', 0.1546930214909133),
#  ('product great', 0.1546922564293346),
#  ('product fulfills', 0.15464232839698855),
#  ('couple things', 0.15446466550945168),
#  ('im unhappy', 0.15438582070318344),
#  ('got husband', 0.1541097655407816),
#  ('great laptophavent', 0.15410223476253679),
#  ('received exactly', 0.15381117318772508),
#  ('happy got', 0.15331851081659939),
#  ('functioning tablet', 0.15265940336819087),
#  ('purchase samsung', 0.15249997791066902),
#  ('love far', 0.15193041971091534),
#  ('definitely pleasing', 0.15178265765410129),
#  ('thought bought', 0.15118331397561116),
#  ('even price', 0.15043681664088221),
#  ('everything awesome', 0.1504044595951117),
#  ('everything need', 0.14965814498704583),
#  ('rest super', 0.14920671619920722),
#  ('doesnt hurt', 0.1490959570204439),
#  ('love looks', 0.14889984629618724),
#  ('bought mom', 0.14833873343451326),
#  ('look products', 0.14822432761166132),
#  ('windows office', 0.14786173689104318),
#  ('lesson cost', 0.14764101997268964),
#  ('long time', 0.14734837400066453),
#  ('light good', 0.14731096361324092),
#  ('trying weeks', 0.14692281079857797),
#  ('youre banking', 0.14687489333520831),
#  ('take town', 0.14663961222122429),
#  ('cheaply build', 0.14630094724376608),
#  ('ever laptop', 0.14617514707946686),
#  ('sad connect', 0.14580929339324855),
#  ('hate cant', 0.1457133916355193),
#  ('waste money', 0.14566744071139426),
#  ('finally got', 0.14483270807496651),
#  ('features much', 0.1446309710645993),
#  ('keyboard rocks', 0.144416056743185),
#  ('works perfect', 0.14419285799905046),
#  ('loving little', 0.14353963360180019),
#  ('love would', 0.142633243681801),
#  ('need internet', 0.14232757424961062),
#  ('chromebook overlook', 0.14226611048767496),
#  ('similar app', 0.14101233291872683),
#  ('simple use', 0.14093954926712191),
#  ('impressed happy', 0.14091994642691683),
#  ('price togo', 0.14081751305181145),
#  ('except screen', 0.14041637468011203),
#  ('problem connecting', 0.14006662073542808),
#  ('school begins', 0.13971871748373682),
#  ('chromebook one', 0.13948779192706229),
#  ('late disappointed', 0.13945599639296408),
#  ('master something', 0.13921436182911234),
#  ('rating stars', 0.1391465278119684),
#  ('seals deal', 0.13905250630610907),
#  ('alternative laptop', 0.13902722134986059),
#  ('work done', 0.13869109500418317),
#  ('comes tablet', 0.13851696038986938),
#  ('complain much', 0.13848543232026411),
#  ('im workstation', 0.13829200253871485),
#  ('recommend anyone', 0.13756675514471303),
#  ('look elsewhere', 0.13733832847076438),
#  ('awesome computer', 0.13626156318149321),
#  ('great buy', 0.13625767839196301),
#  ('tablet laptop', 0.13614436059211266),
#  ('dont get', 0.13590913094060467),
#  ('loads fast', 0.13561526598257276),
#  ('playing youtube', 0.13529474113888815),
#  ('itunes skype', 0.1352087617733671),
#  ('sleek look', 0.13508678306112168),
#  ('got computer', 0.13495543307124802),
#  ('great read', 0.13491312793382837),
#  ('thanks attention', 0.13480790957650998),
#  ('could connect', 0.13470588931934244),
#  ('needs better', 0.13446699299187886),
#  ('satisfactory product', 0.13437420769142716),
#  ('weve happy', 0.13428927381780703),
#  ('like company', 0.13409473254183604),
#  ('top line', 0.13390464514870004),
#  ('find chromebook', 0.13389248833696044),
#  ('sure great', 0.13381041040206393),
#  ('get replace', 0.13343567556446587),
#  ('work many', 0.13231697707296111),
#  ('love shirt', 0.13172079112218502),
#  ('light quiet', 0.13161840455629811),
#  ('still shocked', 0.13130903554174797),
#  ('device issues', 0.13080228692536935),
#  ('even though', 0.13077939123439516),
#  ('got samsung', 0.13065047859666068),
#  ('good travel', 0.13057216390308721),
#  ('see wrong', 0.13015161414736251),
#  ('sy piece', 0.12955566885737491),
#  ('samsung products', 0.12953590530729886),
#  ('student laptop', 0.12947952123753759),
#  ('wife computer', 0.12946079765171897),
#  ('love simplicity', 0.12928457842921762),
#  ('never easier', 0.12917802628885758),
#  ('price super', 0.12917285912909682),
#  ('didnt like', 0.12893547538353944),
#  ('thought thing', 0.12882767695114661),
#  ('wife brand', 0.1286445322046757),
#  ('everything google', 0.12819984776387966),
#  ('tech savy', 0.12748347056370588),
#  ('android phonelike', 0.1272978803852334),
#  ('recently ordered', 0.12725926656492303),
#  ('perfect use', 0.12718242362456955),
#  ('done google', 0.12625061238795501),
#  ('needed new', 0.12624861732908982),
#  ('pretty useless', 0.12602121027262192),
#  ('reading reviews', 0.1255205934424381),
#  ('fast shipping', 0.12534486085813645),
#  ('videos youtube', 0.12532475898800108),
#  ('thing doesnt', 0.12522146970116493),
#  ('youtube videos', 0.12502571143623123),
#  ('weight recommend', 0.12501979894858797),
#  ('buy another', 0.12481274928357125),
#  ('exactly looking', 0.12466031598292054),
#  ('repair replacement', 0.12458832348406046),
#  ('day arrived', 0.12420066797317592),
#  ('good day', 0.12419723724646783),
#  ('get better', 0.12406793388569591),
#  ('tried take', 0.12406725008761056),
#  ('great travel', 0.12401506693520868),
#  ('work either', 0.12397866355497901),
#  ('choose rating', 0.12377605384727564),
#  ('looking ipads', 0.12353304594868456),
#  ('im happy', 0.12345645911885501),
#  ('terrible product', 0.12330882084457835),
#  ('able anything', 0.12316562864858735),
#  ('challenge use', 0.12308417874470989),
#  ('well thought', 0.12274084236340804),
#  ('basically netbook', 0.1222406659118931),
#  ('personal laptop', 0.12186472795784961),
#  ('takes little', 0.12150675575262103),
#  ('absolutely awesome', 0.12141856618171273),
#  ('laptops lightweight', 0.12126322740855963),
#  ('overpriced netbook', 0.12124133768095852),
#  ('ok email', 0.12119218507531909),
#  ('five stars', 0.12097269487300087),
#  ('slim compact', 0.12085291276316903),
#  ('lightweight month', 0.1206871566596517),
#  ('work games', 0.12051963348146022),
#  ('understand inexpensive', 0.12047854950185689),
#  ('chose cause', 0.12036275911683494),
#  ('hard understand', 0.12023697670660116),
#  ('fast boots', 0.12006708724415778),
#  ('equipped sucks', 0.11878668047267048),
#  ('definitely fallen', 0.11873277496715609),
#  ('fire love', 0.11871881613140332),
#  ('book works', 0.11871163301395254),
#  ('chromebook perfect', 0.11855436294213587),
#  ('always anyhow', 0.11809927195442518),
#  ('fun returning', 0.11799593386424512),
#  ('easier deal', 0.11674627991340904),
#  ('everything cloud', 0.11669439237781436),
#  ('asked refund', 0.11652277365760406),
#  ('ths system', 0.11650955084547408),
#  ('love ease', 0.11637493733557748),
#  ('got lemon', 0.11601200700462128),
#  ('best thing', 0.11599696862101276),
#  ('worst purchase', 0.11548258843086193),
#  ('reliable pc', 0.11547596813894566),
#  ('brought one', 0.11541462022845771),
#  ('right love', 0.11538111332027952),
#  ('flimsy well', 0.11527707831020968),
#  ('read products', 0.11519344319859869),
#  ('chromebook doesnt', 0.11519278008161352),
#  ('particular reason', 0.11511533189648558),
#  ('quite order', 0.11485903072800353),
#  ('worth price', 0.11459653926939664),
#  ('okay want', 0.11421810743242215),
#  ('happy chromebook', 0.11410365593682428),
#  ('thank much', 0.11400470562757316),
#  ('product simple', 0.11390121699772066),
#  ('regular computer', 0.11386430650997963),
#  ('months worked', 0.11367103656893071),
#  ('simple games', 0.11364004602274452),
#  ('reason didnt', 0.11355621122591912),
#  ('christmas time', 0.11350532471327839),
#  ('products fault', 0.11349183631446341),
#  ('issues getting', 0.11347681439704739),
#  ('internet machine', 0.11342781543387853),
#  ('back amazon', 0.11332689964824028),
#  ('unit light', 0.11301573070384102),
#  ('advertised chrome', 0.1129974907166105),
#  ('need online', 0.11291026263870629),
#  ('anything bad', 0.11283749107696676),
#  ('small inexpensive', 0.1126244489284027),
#  ('much better', 0.11218278180571774),
#  ('route go', 0.11211700174915429),
#  ('bought girlfriend', 0.11196965378937757),
#  ('forget using', 0.11180148670647817),
#  ('hardware bad', 0.11159059635787727),
#  ('microsoft office', 0.11144600626804867),
#  ('would go', 0.11143275709907416),
#  ('productive cant', 0.11135438907706043),
#  ('updates automatically', 0.11076126443387088),
#  ('great bargain', 0.11027323713566155),
#  ('old samsung', 0.1102679707630886),
#  ('good browsing', 0.11019203407963388),
#  ('slim lightweight', 0.110152750623506),
#  ('give stars', 0.1100768447716427),
#  ('great quality', 0.10991567987537768),
#  ('netbook target', 0.10989247241828957),
#  ('every time', 0.10976170895259574),
#  ('like computer', 0.10973815999821493),
#  ('found negative', 0.10966634665319532),
#  ('isnt work', 0.10913069375092449),
#  ('lasted week', 0.10909035456381821),
#  ('using days', 0.10889051728914129),
#  ('take hawaii', 0.10883944240750641),
#  ('needs get', 0.10882068433507013),
#  ('everything says', 0.10881495020109715),
#  ('small old', 0.10864812824092374),
#  ('pay get', 0.10862202720982922),
#  ('going get', 0.108267651469659),
#  ('back computer', 0.10783103951998313),
#  ('satisfied productthis', 0.1076617953169568),
#  ('need desktop', 0.10765982312487046),
#  ('streaming social', 0.10762175199875752),
#  ('second one', 0.10734479192768617),
#  ('main thing', 0.10700413339169494),
#  ('nice lightweight', 0.10658199486251825),
#  ('screen adequate', 0.10645476827435219),
#  ('ordered gift', 0.10627395496757072),
#  ('read use', 0.10622376500923124),
#  ('keyboard touchpad', 0.10600185474514033),
#  ('laptop great', 0.10592708623830047),
#  ('id recommend', 0.10580671097352168),
#  ('functional computer', 0.10547812453241596),
#  ('recommend product', 0.10546591781402299),
#  ('machine ideal', 0.10538549352163525),
#  ('get see', 0.10528911632671036),
#  ('good quality', 0.10522140091661424),
#  ('chromebook limited', 0.10500189679067871),
#  ('charge piece', 0.10436571310746165),
#  ('begin forget', 0.10433702434126735),
#  ('think good', 0.10429950347020296),
#  ('amazon customer', 0.10428335039820558),
#  ('bought purpose', 0.10419303665318276),
#  ('expect laptop', 0.10417323570956787),
#  ('decent hardware', 0.10413500057144341),
#  ('took hour', 0.10408598321555686),
#  ('lite love', 0.10362640643251393),
#  ('brilliant replacement', 0.10350020252692346),
#  ('look chromebooks', 0.10318823898182297),
#  ('got tired', 0.10266041421468282),
#  ('get google', 0.10255995077716513),
#  ('email research', 0.10246041057026636),
#  ('chromes weight', 0.10244244220067111),
#  ('product expecting', 0.10237603577617535),
#  ('great deal', 0.10234470076779473),
#  ('better tablet', 0.10222659381781807),
#  ('users add', 0.10220643416363552),
#  ('productively highly', 0.10211082419080447),
#  ('replacement doesnt', 0.10189859859858438),
#  ('perfect lightweight', 0.10161765617518399),
#  ('havent problems', 0.10141970572853407),
#  ('money like', 0.10087094611155921),
#  ('laptop adorable', 0.10085387571514177),
#  ('docs returning', 0.10080490109607904),
#  ('say product', 0.10073444502099735),
#  ('hard open', 0.10071228607335568),
#  ('limitations trying', 0.10066576320216943),
#  ('work college', 0.10031156951998485),
#  ('word difficult', 0.10031062236699081),
#  ('gave product', 0.10022660549534726),
#  ('like weight', 0.1002184593723655),
#  ('unhappy item', 0.10021047604797936),
#  ('reviews decided', 0.10016207266424186),
#  ('google awesome', 0.099648052420824473),
#  ('laptop gb', 0.09944330426605702),
#  ('functional acer', 0.099294949419120024),
#  ('nothing like', 0.098964321391392385),
#  ('passed month', 0.098810307158181329),
#  ('fast delivery', 0.098727177418090353),
#  ('nothing problems', 0.098675805754155202),
#  ('excellent machine', 0.098572732634759103),
#  ('make quite', 0.098472122059227327),
#  ('portable laptop', 0.098390125082034166),
#  ('run cant', 0.098326700685205215),
#  ('something last', 0.098273012845588495),
#  ('lightweight thin', 0.097795026618035366),
#  ('love compact', 0.097739490477680394),
#  ('accurate time', 0.097670357946578842),
#  ('year old', 0.097551657086608096),
#  ('beyond needs', 0.097220361727857987),
#  ('bought months', 0.097167634543748063),
#  ('samsung chrome', 0.097136601136590089),
#  ('forwatching movies', 0.096985060888333571),
#  ('reallyy hard', 0.096929472918115628),
#  ('much use', 0.096778791121685789),
#  ('product choose', 0.096403592072543495),
#  ('well either', 0.096371932903597426),
#  ('nice product', 0.09626015279807279),
#  ('school homework', 0.096192736493881437),
#  ('came defect', 0.095984090887490506),
#  ('hardware given', 0.095785927536962315),
#  ('fixes issue', 0.095725477340390108),
#  ('even powerful', 0.095537484767477698),
#  ('casual home', 0.095467403168780593),
#  ('loved low', 0.095446705980098301),
#  ('love useful', 0.095342298003028292),
#  ('chromebook chance', 0.09512386818927665),
#  ('great pc', 0.094906131438274643),
#  ('chromebook many', 0.094730376058744015),
#  ('could easily', 0.094472776445977832),
#  ('great light', 0.094456464984228827),
#  ('purchase another', 0.094426610093522337),
#  ('chromebooks seeing', 0.094410166117988553),
#  ('little getting', 0.094357444079916739),
#  ('social mediaetc', 0.094194411886032753),
#  ('runs well', 0.094163554978828515),
#  ('really google', 0.09411600637652752),
#  ('surprised light', 0.09409326036825269),
#  ('work reliably', 0.094006651770540836),
#  ('customer thanks', 0.093959949322976674),
#  ('recommend friend', 0.093889123245909964),
#  ('reviews interest', 0.093865704052699853),
#  ('wife wanted', 0.093508829255660508),
#  ('development work', 0.09342882372910094),
#  ('works excellent', 0.093352854603243579),
#  ('decent camera', 0.093327513739332638),
#  ('would perfect', 0.093326185934222108),
#  ('take works', 0.093312728284376201),
#  ('youre set', 0.093039180757436682),
#  ('great prize', 0.093018047306010251),
#  ('trying overcomei', 0.09292359740677246),
#  ('good tool', 0.092851437230503861),
#  ('gotten tablet', 0.092748273547538049),
#  ('using chromebook', 0.092628636684912585),
#  ('love light', 0.092427452691947659),
#  ('concept speed', 0.092306614787450114),
#  ('perfect people', 0.091806221798360108),
#  ('gave mac', 0.091798390707526406),
#  ('uses facebook', 0.091564758510529601),
#  ('another one', 0.091428793264317978),
#  ('recomend anyone', 0.091392777229112807),
#  ('great couple', 0.091334846215883628),
#  ('bought chrome', 0.091322386349901169),
#  ('simple youtube', 0.091216494320777136),
#  ('one thing', 0.090666637607500197),
#  ('wanted laptop', 0.090598586342778301),
#  ('purchased children', 0.090517883295495441),
#  ('affordabilitysimplicityease use', 0.090485250652734606),
#  ('computer money', 0.090451286846222542),
#  ('figure return', 0.090434693530345778),
#  ('good little', 0.090104250141189765),
#  ('daughter happy', 0.090018087212513476),
#  ('unhappy product', 0.089690392397344762),
#  ('computer nothing', 0.089654045545949759),
#  ('works fine', 0.08961371931606546),
#  ('chromebook idea', 0.089579102516629858),
#  ('perfect students', 0.088961019441518727),
#  ('couldnt make', 0.088959082082524038),
#  ('ripped less', 0.08881643485207974),
#  ('computer works', 0.08863085560805993),
#  ('rarely lagsi', 0.088556797498993298),
#  ('another pc', 0.088197995940786783),
#  ('thank marcella', 0.08817396547882092),
#  ('virus hand', 0.088107031499546337),
#  ('im process', 0.08792297585212594),
#  ('daily task', 0.087799711177859327),
#  ('like chrome', 0.087736254976370068),
#  ('everything pages', 0.087719101612284925),
#  ('work related', 0.087664840137178374),
#  ('book fine', 0.087573998322263674),
#  ('unexpected limitations', 0.087536599882159727),
#  ('keep looking', 0.087488398330170317),
#  ('return two', 0.087200970709853332),
#  ('tried two', 0.087127892014348923),
#  ('productsdont buy', 0.087109498525224871),
#  ('reviews mentioned', 0.086997764199036709),
#  ('cool price', 0.086947468382360255),
#  ('bought year', 0.086831908914190917),
#  ('cannot tell', 0.086828665976150229),
#  ('buy chromebooks', 0.086826312904338704),
#  ('apparently order', 0.086800188807729467),
#  ('one pleased', 0.086747197865284273),
#  ('basic pc', 0.086687867497881113),
#  ('bought thing', 0.086058681654205119),
#  ('physically comes', 0.085979716032731773),
#  ('little hard', 0.085566403491980136),
#  ('like sporty', 0.085481487110464174),
#  ('pros speed', 0.085415937843482892),
#  ('computer everything', 0.085369049992978452),
#  ('disappointment browse', 0.085283443926245012),
#  ('ordered daughter', 0.085273768485612494),
#  ('items company', 0.085173997930091616),
#  ('never got', 0.085102590533665284),
#  ('drive everything', 0.08492966672656703),
#  ('buy one', 0.084853434697371041),
#  ('look book', 0.084810145071306742),
#  ('chose samsung', 0.084796663762887942),
#  ('life pretty', 0.084549818972129293),
#  ('cant wait', 0.084382493405372683),
#  ('thing tiny', 0.084322650039516001),
#  ('think great', 0.084299847269197106),
#  ('anyone need', 0.084134337222449784),
#  ('homework social', 0.084073626997878514),
#  ('tried return', 0.08403017127947765),
#  ('rather tablet', 0.084003106927681828),
#  ('good important', 0.083936280837600075),
#  ('google samsung', 0.083678548436804334),
#  ('get much', 0.083659617613309978),
#  ('difficult work', 0.083527644313998409),
#  ('better product', 0.08337883049528419),
#  ('lasts hours', 0.0832572336171125),
#  ('doesnt windows', 0.083060994131821872),
#  ('looking foe', 0.082684598627860956),
#  ('feels looks', 0.08263086450327585),
#  ('away tobacco', 0.082468403009902727),
#  ('tried used', 0.082326308369840784),
#  ('much easier', 0.081888080277780842),
#  ('driveyou get', 0.081602965492589816),
#  ('need new', 0.081578122163921171),
#  ('chrome combined', 0.081527835285990169),
#  ('bought tablet', 0.081360656169165657),
#  ('perfect might', 0.081349394837309547),
#  ('lots google', 0.081301313010634618),
#  ('tobacco fields', 0.08097748751760224),
#  ('really like', 0.080907467006279113),
#  ('month issues', 0.080701045351750517),
#  ('lot okay', 0.080509769878929077),
#  ('looking portable', 0.080497361449396496),
#  ('basic laptop', 0.080348910684391164),
#  ('laptop lightweight', 0.080096784162330931),
#  ('works well', 0.080063152713290064),
#  ('good facebook', 0.079939560708427837),
#  ('wish stated', 0.079919128582493781),
#  ('wifi connection', 0.079841673578817454),
#  ('another samsung', 0.079833150694658739),
#  ('lightweight wow', 0.079818290557026952),
#  ('disappointed quality', 0.079791060929472413),
#  ('cant use', 0.079708699473966957),
#  ('turbotax online', 0.079511099005736385),
#  ('sure knew', 0.079368325730766423),
#  ('unit fastvery', 0.079197647152636774),
#  ('watch netflix', 0.078987417637356158),
#  ('purchased product', 0.078962277827696117),
#  ('easy one', 0.078805789794208742),
#  ('device enjoy', 0.078764053123595468),
#  ('ask thank', 0.078372414451819319),
#  ('ecosystem enjoy', 0.078360158594745613),
#  ('lcd screen', 0.078059229238399405),
#  ('little helper', 0.07736970574823189),
#  ('fine recommended', 0.077310978742256106),
#  ('recent refund', 0.077252656380295728),
#  ('purchased chromebook', 0.077050648239204919),
#  ('selling computer', 0.076924610696317161),
#  ('ease use', 0.076891103516672665),
#  ('considering purchase', 0.076723680842463601),
#  ('need laptop', 0.076683856403212541),
#  ('bought wife', 0.07617910935844939),
#  ('sure refurbished', 0.075929868905369693),
#  ('basic functionality', 0.075852782463139257),
#  ('adjust settings', 0.075690237413990544),
#  ('product anyone', 0.075621195896618601),
#  ('longterm work', 0.075549477284693148),
#  ('husband uses', 0.075530734078896211),
#  ('college student', 0.075364988896254204),
#  ('runs hot', 0.075295163092684969),
#  ('use needs', 0.075270929047355897),
#  ('use itunes', 0.075261489392127678),
#  ('really nice', 0.075231614537630692),
#  ('happy supporter', 0.075035789948700596),
#  ('chromebooks quite', 0.074931871622770915),
#  ('months cool', 0.074812233160972949),
#  ('im races', 0.074789698028891238),
#  ('later get', 0.074559227233656877),
#  ('chromeosvery recommended', 0.074259504393000844),
#  ('excellent products', 0.0741313347228547),
#  ('blog reader', 0.074125246401634093),
#  ('forget apps', 0.074107071470409042),
#  ('exactly expecting', 0.073757186044236409),
#  ('good purchase', 0.07370770716020561),
#  ('meeting needs', 0.073560661524688833),
#  ('easy take', 0.073379751235853274),
#  ('recommend friends', 0.073345239490925959),
#  ('power cords', 0.072975850502492209),
#  ('getting apps', 0.072906207602580084),
#  ('fast dependable', 0.072851130998714514),
#  ('office programs', 0.072846686121295939),
#  ('got great', 0.072787039845638432),
#  ('price perfect', 0.072728134635995895),
#  ('recommend getting', 0.072502822610225656),
#  ('friend reccomended', 0.072480315040286847),
#  ('internal storage', 0.072442003260073315),
#  ('music surfing', 0.072353996540719723),
#  ('design hard', 0.071894441579807192),
#  ('chromebooks refunds', 0.07182861407989817),
#  ('works effortlessly', 0.071726769130360468),
#  ('wasting time', 0.071558169353336143),
#  ('suite purchase', 0.071501790925952949),
#  ('flash consistently', 0.071469176107597773),
#  ('price would', 0.0714062643291479),
#  ('buy worst', 0.071392796209938256),
#  ('bought replace', 0.071253173981863038),
#  ('days love', 0.071250805124147387),
#  ('go cant', 0.071200723931044207),
#  ('couldnt find', 0.071093233904294256),
#  ('carry read', 0.070918703377684522),
#  ('gets vote', 0.070912422947891879),
#  ('connect internet', 0.070823537591412494),
#  ('issues model', 0.070787006167803229),
#  ('great started', 0.070698371288044737),
#  ('one fault', 0.07064240022819053),
#  ('good fit', 0.070380662951293929),
#  ('google hangout', 0.070298547955892771),
#  ('impressed samsung', 0.070260761807209679),
#  ('amazon thank', 0.069971072693544356),
#  ('represents computing', 0.069799601091404068),
#  ('enough get', 0.069775280456556635),
#  ('hesitant first', 0.069678208732599528),
#  ('light aesthetically', 0.069673068187662876),
#  ('im returning', 0.069646891902398492),
#  ('play games', 0.069611113625140553),
#  ('piece broken', 0.069599794266462067),
#  ('pretty good', 0.069486078861819706),
#  ('useful computer', 0.06932138216899697),
#  ('device peers', 0.069259509847880721),
#  ('yes basic', 0.069081573639622113),
#  ('follows products', 0.06895583073075981),
#  ('machine enables', 0.068946797812259403),
#  ('amazon today', 0.06888854798775694),
#  ('work box', 0.068798113488445722),
#  ('would nice', 0.068731901123585612),
#  ('unit money', 0.068714335655804815),
#  ('great purchase', 0.068578593418944622),
#  ('every thing', 0.068529530826191135),
#  ('price highly', 0.068448562345245198),
#  ('well complaints', 0.068295601594043367),
#  ('viz maybe', 0.068195993530872606),
#  ('trinidad disappointed', 0.068046365404472495),
#  ('based netbook', 0.068010998984925741),
#  ('computer smartphonetablet', 0.067978227720559226),
#  ('great back', 0.067948735637396993),
#  ('pc anywhere', 0.067738525523483084),
#  ('primary pc', 0.067331790198308872),
#  ('need recommend', 0.067235060768315646),
#  ('password hints', 0.066943966549026734),
#  ('internet horrendous', 0.066876163568025254),
#  ('wi fi', 0.066827639419370755),
#  ('amazon seller', 0.066824018715392314),
#  ('item yesterday', 0.066548096261682205),
#  ('easy also', 0.066388801744453593),
#  ('add wish', 0.066221309915322574),
#  ('worked right', 0.066177502450619943),
#  ('could play', 0.066172663107593094),
#  ('advertised download', 0.065924215551301554),
#  ('steal long', 0.065583224263980999),
#  ('told turn', 0.065426065466130154),
#  ('important keep', 0.06521597379348254),
#  ('college students', 0.065210256033074468),
#  ('cannot print', 0.065187049082471318),
#  ('would cool', 0.065017326085771487),
#  ('picking second', 0.064954090230030112),
#  ('understand wish', 0.064852610722640161),
#  ('switch easy', 0.064721472894888471),
#  ('expected computer', 0.06453203959177306),
#  ('things like', 0.064505258802215915),
#  ('boot immediately', 0.064258947832315297),
#  ('machine rocksno', 0.064250559619309436),
#  ('worst computer', 0.063945044085714442),
#  ('directly navigate', 0.063902914184993109),
#  ('road back', 0.063761119291045665),
#  ('emailyour friends', 0.063650822367794943),
#  ('run java', 0.063621785884696178),
#  ('get stars', 0.06356476500906337),
#  ('gave grandma', 0.063552744008491174),
#  ('keep forget', 0.063391780967859121),
#  ('os difficult', 0.063356593358708191),
#  ('priced well', 0.063344843309899049),
#  ('housedo need', 0.063066791837264394),
#  ('students techies', 0.063040380801243107),
#  ('traveling better', 0.062871561385053676),
#  ('recommend laptop', 0.062871223223328179),
#  ('wanted use', 0.062857654975556357),
#  ('really must', 0.062807560371969384),
#  ('phone thats', 0.062672945925972307),
#  ('mean stuff', 0.062615200327969758),
#  ('would buy', 0.06259712189743491),
#  ('work ok', 0.062581610902543994),
#  ('really liked', 0.062447796599740805),
#  ('regretful purchase', 0.062394958087129242),
#  ('google cloud', 0.062359958143985102),
#  ('download itunes', 0.062157961488617866),
#  ('hope helps', 0.06215560948333855),
#  ('isnt great', 0.062108675969083364),
#  ('know begin', 0.062092553206389726),
#  ('quality user', 0.062026980016013027),
#  ('hate laptop', 0.062013106170615367),
#  ('one almost', 0.061913581204233674),
#  ('ive chromebook', 0.061857242477081839),
#  ('chromebook month', 0.061774400029887835),
#  ('easier figure', 0.06157695077436711),
#  ('worked great', 0.061486625696501526),
#  ('device printer', 0.061414020347851761),
#  ('office staff', 0.061386274930051915),
#  ('cannot used', 0.061374221485036191),
#  ('internet access', 0.061237890005743471),
#  ('understanding chrome', 0.061160292209467233),
#  ('fast quiet', 0.061147345483764388),
#  ('getting much', 0.060771034231655162),
#  ('email social', 0.060756002361958807),
#  ('applications google', 0.06050465270185152),
#  ('returning laptop', 0.060374167996468421),
#  ('much rather', 0.060272065878547963),
#  ('exceeded expectations', 0.060185340048598435),
#  ('worked perfectly', 0.060161713874376972),
#  ('quite expected', 0.059827972148143525),
#  ('would easier', 0.05972721687193748),
#  ('problem wep', 0.059572767965472763),
#  ('right size', 0.059439825880874243),
#  ('lightweighted good', 0.059363635257305619),
#  ('price chromebook', 0.059220481054727873),
#  ('show everything', 0.059183652776263911),
#  ('poor quality', 0.059140592729290536),
#  ('go wrong', 0.059028256547066289),
#  ('chrome books', 0.058682415620880855),
#  ('wifi available', 0.058634081719406546),
#  ('want small', 0.058611601097303546),
#  ('received quit', 0.058605758836623792),
#  ('keep price', 0.058492972291226866),
#  ('work complaints', 0.058335558691004194),
#  ('childrenits great', 0.058308468212521856),
#  ('ordered thought', 0.058296402844884729),
#  ('fast pleased', 0.05820674144468551),
#  ('correct options', 0.05814486323371066),
#  ('paid juan', 0.058105586115096849),
#  ('computer mostly', 0.058043737650782586),
#  ('something like', 0.057993946349878103),
#  ('fist day', 0.057947373483977958),
#  ('girlfriend everything', 0.057901544032608249),
#  ('picked christmas', 0.057838166454150151),
#  ('recommend travel', 0.057739037909106526),
#  ('videobrowsingschool computer', 0.057691119624268837),
#  ('book powerful', 0.057685536851823482),
#  ('want easy', 0.057625014212354116),
#  ('everything works', 0.057539783522144242),
#  ('laptop thin', 0.057508757987910074),
#  ('got girlfriend', 0.057311912835577912),
#  ('line least', 0.057181402634680162),
#  ('product market', 0.057158254018556884),
#  ('acer intel', 0.057000202361163141),
#  ('modles horrible', 0.056912142713750634),
#  ('better choice', 0.056839186852068832),
#  ('anti virus', 0.056814420872576807),
#  ('absolutely love', 0.05660820740199532),
#  ('small price', 0.056573283484302794),
#  ('reply someone', 0.056450590638605379),
#  ('net need', 0.056329016932315894),
#  ('set keyboard', 0.056084361618574552),
#  ('price quality', 0.055978124724732008),
#  ('unbeatable great', 0.055912495242308187),
#  ('second machine', 0.055890793362678055),
#  ('much taking', 0.055723404958844945),
#  ('docs offline', 0.055722774939335876),
#  ('screen four', 0.055706532903189478),
#  ('desired wasnt', 0.055686157136117867),
#  ('great notebook', 0.05565750718398732),
#  ('notebook apple', 0.055638754768451391),
#  ('laptop love', 0.055512645558866855),
#  ('movies airplane', 0.055464395594659766),
#  ('put linux', 0.055426005332321004),
#  ('job well', 0.055373998256342843),
#  ('time apparent', 0.055276155116498395),
#  ('link nothing', 0.055274767849451054),
#  ('came accross', 0.055269957317284492),
#  ('looking something', 0.055134699120678338),
#  ('great really', 0.054982569770409516),
#  ('samsung google', 0.054874687315579471),
#  ('monthswhat think', 0.054572487945893193),
#  ...]

# %% [markdown]
# ## Pos / Neg Feature Extraction

# %%
pos_features= {}
neg_features= {}

for feature in tqdm(list(features)):
    f_exist = product_review.loc[product_review['clean_text'].apply(lambda x : feature[0] in x)]
    prob = np.mean(f_exist['label'])
    if (prob >= 0.8) and (2 < len(f_exist)):
        pos_features[feature[0]] = feature[1]
    if (prob < 0.2) and (2 < len(f_exist)):
        neg_features[feature[0]] = feature[1]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 1409/1409 [00:01<00:00, 1234.77it/s]

# %%
sorted(pos_features.items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('highly recommend', 0.87898669162667864),
#  ('great computer', 0.8046045002811375),
#  ('little laptop', 0.66976043969992993),
#  ('cant beat', 0.54422319491550597),
#  ('battery life', 0.51861198204402159),
#  ('definitely recommend', 0.50647388151164352),
#  ('love samsung', 0.47555381398482749),
#  ('little computer', 0.38755039203963332),
#  ('price cant', 0.38066664218957519),
#  ('love chromebook', 0.34315464599151851),
#  ('great machine', 0.28919535335538654),
#  ('dont want', 0.28814633830916364),
#  ('lightweight fast', 0.2782414208656207),
#  ('great little', 0.25819498963119836),
#  ('love little', 0.25376303973669823),
#  ('lightweight compact', 0.24962186072143275),
#  ('fast efficient', 0.24696321462542439),
#  ('love thing', 0.23100965241563437),
#  ('cloud storage', 0.223922493382086),
#  ('love chrome', 0.2181894176402894),
#  ('chromebook great', 0.19484945476175652),
#  ('little chromebook', 0.18336612115296402),
#  ('easy use', 0.17120024824403274),
#  ('use love', 0.16944056413880537),
#  ('everything need', 0.14965814498704583),
#  ('long time', 0.14734837400066453),
#  ('works perfect', 0.14419285799905046),
#  ('simple use', 0.14093954926712191),
#  ('great buy', 0.13625767839196301),
#  ('needed new', 0.12624861732908982),
#  ('great travel', 0.12401506693520868),
#  ('chromebook perfect', 0.11855436294213587),
#  ('everything cloud', 0.11669439237781436),
#  ('worth price', 0.11459653926939664),
#  ('product simple', 0.11390121699772066),
#  ('like computer', 0.10973815999821493),
#  ('id recommend', 0.10580671097352168),
#  ('could easily', 0.094472776445977832),
#  ('recommend friend', 0.093889123245909964),
#  ('love light', 0.092427452691947659),
#  ('computer money', 0.090451286846222542),
#  ('drive everything', 0.08492966672656703),
#  ('buy one', 0.084853434697371041),
#  ('anyone need', 0.084134337222449784),
#  ('really like', 0.080907467006279113),
#  ('ease use', 0.076891103516672665),
#  ('every thing', 0.068529530826191135),
#  ('wanted use', 0.062857654975556357),
#  ('internet access', 0.061237890005743471),
#  ('absolutely love', 0.05660820740199532),
#  ('work computer', 0.053645647902041613),
#  ('chrome apps', 0.050461780257443918),
#  ('great laptop', 0.046511297655959558),
#  ('fast great', 0.045204587484908486),
#  ('thing dont', 0.038071448140185205),
#  ('really love', 0.037609763533526977),
#  ('excellent purchase', 0.030642809563885924)]

# %%
sorted(neg_features.items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('get pay', 1.0282845110228394),
#  ('return policy', 0.45630384165718674),
#  ('sent back', 0.40249849049544523),
#  ('ended returning', 0.3663350291530123),
#  ('real laptop', 0.31767334136549552),
#  ('internet connection', 0.19701883558495237),
#  ('doesnt work', 0.19138926842503767),
#  ('quality product', 0.17651254192688387),
#  ('thought would', 0.16843233096711244),
#  ('without internet', 0.16805414088108059),
#  ('sending back', 0.16608176029626806),
#  ('money back', 0.15866125592581604),
#  ('waste money', 0.14566744071139426),
#  ('even though', 0.13077939123439516),
#  ('buy another', 0.12481274928357125),
#  ('able anything', 0.12316562864858735),
#  ('back amazon', 0.11332689964824028),
#  ('google samsung', 0.083678548436804334),
#  ('get much', 0.083659617613309978),
#  ('use itunes', 0.075261489392127678),
#  ('connect internet', 0.070823537591412494),
#  ('wi fi', 0.066827639419370755),
#  ('things like', 0.064505258802215915),
#  ('worst computer', 0.063945044085714442),
#  ('download itunes', 0.062157961488617866),
#  ('worked great', 0.061486625696501526),
#  ('dont buy', 0.038617941318474194),
#  ('cant figure', 0.021575595454979311),
#  ('product first', 0.018348316816768705)]

# %% [markdown]
# ## Instance Pick

# %%
pos_reviews_explanations = list(product_review.loc[product_review['label'] == 1]['explanations'])
neg_reviews_explanations = list(product_review.loc[product_review['label'] == 0]['explanations'])
pos_chosen, _ = submodular_pick(pos_reviews_explanations, pos_features, k = 10)
neg_chosen, _ = submodular_pick(neg_reviews_explanations, neg_features, k = 10)

# %%
for review in pos_chosen:
    row = product_review.loc[product_review['clean_text'] == review[1]]
    text = row['reviewText'].iloc[0]
    label = row['label'].iloc[0]
    print(text,label,'\n')
# Out:
# This is a great little chromebook.  I havent had any problems with it so far, and i've dropped it quite a few times.  Great for streaming video online, watching netflix and hulu, and playing games.  Very lightweight and portable.  There is no CD/DVD drive, which can be kind of lame sometimes, but otherwise a great computer. 1
#
# Sper easy to use, lightweight, great for homework, scheduling, and internet based projects or work. Very easy to set up multiple users so we use this computer for our 4 kids. Love this little laptop. 1
#
# Great for travel or the coffee shop etc. But remember it needs wifi.Everything that I expected. I would highly recommend it. 1
#
# Simple to use. No viruses, very good speed, light to carry. Pretty much everything you need. Sound and volume average. Would definitely recommend. 1
#
# easy to use - love the size of the keyboard. the book is lightweight and easy to carry. i am still learning about all the things it does.  also like watching tv on it at night in bed while going to sleep.  just set it in the night stand, 1
#
# For the price, you can't beat this laptop. Web browsing and creating documents is about all it can do, but that's all I need it to do. If you can say the same thing then get this chrome book. 1
#
# I absolutely love this thing. I wish I had purchased a larger screen, but at the time this is what I could afford. I frequently use Google products so it was a great transition from my PC laptop. Over a year later, the battery still holds a charge for a long time, turns on/shuts down quickly, and is very lightweight. I love this thing. 1
#
# I love this samsung chromebook. Super light and operates just as fast as any computer. wifi connection is great. would definitely recommend to friends. 1
#
# I am so impressed with this chromebook. No more microsoft for me. It exceeds my expectation. NO hard drive everything is in the cloud 1
#
# LOVE my chromebook.  It was hard to get used to Chrome OS at first but now it's the only computer I use.  I would reccomend the chromebook to anyone who's looking for a lightweight, very portable and very functional computer. 1

# %%
for review in neg_chosen:
    row = product_review.loc[product_review['clean_text'] == review[1]]
    text = row['reviewText'].iloc[0]
    label = row['label'].iloc[0]
    print(text,label,'\n')
# Out:
# Everything was awesome with with notebook, perfect size  , starts up fast as heck from a cold start, looks good  has all the features, but all the sudden mine just shut off-.  and  a white light  blinked, i tried messing with the power cable and differnt oulets ect. but no luck , so good luck if u get one , looks like you get what you pay for. 0
#
# I sent it back. Amazon deserves 5 stars for its swift, efficient return policy that had UPS pick up this defective product at my door free of charge and then issued a full refund. My cromebook would not stay connected to the internet. Every time you click on a new web page it has to search for a connection again and reconnect making this the slowest internet browser on the market which is a serious charge for a product that does not work without an internet connection. 0
#
# Would be cool if it functioned but now it's an expensive paperweight. Very disappointed. If you buy, get it somewhere with a better return policy. 0
#
# I loved the look and feel of the laptop but it was very limited with what it could do.  I didn't realize when I purchased it that it would not download Java which is a requirement for my college work.  There were many other features that did not work out for me and my schoolwork so I sent it back. 0
#
# Ended up returning it. It kept restarting doing the most basic functions like surfing the internet. Would not recommend it. 0
#
# The Samsung Chromebook is little more than a $250 wi-fi platform.  Yes, the keyboard is nice, display crisp and battery strong, but you can't even use Google Earth, let alone any windows-based programs, including word processing.  Heck, there isn't even a delete key (unless I haven't found it yet).  The two-finger drag on the pad is helpful.  Besides that, save your money for awhile and get a real laptop. 0
#
# The mouse doesnt work as well as i'd like, and the back hinge popped open. the build is weak and flimsy. however, the computer works well for 95% of my situations and is nice and lightweight. The other 5% i can use the built in remote desktop to use a windows pc from anywhere. 0
#
# Great quality product love the size. The only thing I wish I would have looked at the Google Chrome thing more. I didn't really know what it was or how it worked, I own an iphone and have ever only owned hp products powered by windows so this chrome is very difficult to operate and I have taken some time to figure it out. I also can't figure out how to get itunes and am very disappointed:( 0
#
# you need internet to use basic functions. you cannot even log into the computer with out it. you are stuck browsing on guest mode and cannot access any files without internet. 0
#
# I am not impressed with this item at all. Not sure if it's this particular unit but it keeps knocking out our wi fi. We are sending it back. 0

# %% [markdown]
# ## TextRank

# %%
pos_reviews = list(product_review.loc[product_review['label'] == 1]['clean_text'])
neg_reviews = list(product_review.loc[product_review['label'] == 0]['clean_text'])
reviews = pos_reviews + neg_reviews
tokens = [review.split() for review in reviews]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(sentence_tokens) for sentence_tokens in tokens]

# %%
ratio = 20 / len(reviews)
print(ratio)
# Out:
# 0.02564102564102564

# %%
textrank_summa_pos = summarization.summarize('. '.join(pos_reviews), ratio=ratio)
textrank_summa_neg = summarization.summarize('. '.join(neg_reviews), ratio=ratio)

# %%
for summa in textrank_summa_pos.split('.')[:-1]:
    row = product_review.loc[product_review['clean_text'] == summa.strip()]
    text = row['reviewText'].iloc[0]
    label = row['label'].iloc[0]
    print(text,label,'\n')
# Out:
# I bought two of these for my kids aged 8 and 10 so they could play Flash games without taking my MacBook Pro. The older child has also started using Google Drive apps for school reports and presentations as well. One obvious shortcoming I discovered when setting up their accounts is that Google requires that users be 13 years old to get an account so I had to set myself up as admin on each of their devices and then use my birthday when setting up their individual accounts in order to get the free cloud storage for each device (since the free storage is one per account, they had to be the registered users). Google's commercials seemed to advertise a laptop for everyone (including kids) so I'm not sure how I was &#34;supposed&#34; to resolve the issue other than lying about their age (and accepting responsibility for monitoring their internet usage). The Chromebooks are plastic and not as solid as a unibody MBP, as you might expect - picking one up by the front corner while it is open results in the touchpad engaging (due to flex), and some of the keys often get stuck down, but other than these minor faults they are great devices with impressive battery life. 1
#
# Well coming from carrying around a full size laptop this thing feels like A paperclip, It's super light, fast, With A Nice, Clean design. It's all powered by Google Chrome, Which is a fast simple browser. It's perfect for an older person, Student on  budget, Or just to have around the house. It's not made for extensive video editing or gaming, But its perfect for Facebook, Youtube, Emails, School work Ect Oh and the battery last forever I can stay on it for hours and hours without charging. 5*, Cant think of anything bad. 1
#
# I purchased this Chromebook for my 8 and 10 year old sons to use for school projects and personal entertainment.  They've had it long enough that I feel confident saying that it was an excellent choice.Among its many attributes, I'd highlight low cost, light weight, intuitive operation, easy access to docs and Google Drive files from other PCs, and a surprisingly broad range of Chrome apps. 1
#
# I would recommend this for someone looking for basic computer on the go. It is easy to use, fast and compact and light to carry. It serves basic needs for those wanting to access e-mail and the Internet in a hurry. I'm quite happy with this purchase as a companion computer. For someone who doesn't use a lot of office programs, it can also function on its own as your personal laptop. 1
#
# This machine rocks.no, it won't completely replace your laptop because it doesn't run Quickbooks or other similar 3rd party apps, but if you can get by with a great browser (Chrome), access to the web, and google web applications, this is a perfect solution. I've read where the screen on the HP is better, and it would be great if there were lighting for the keyboard, but other than that, go for it. These things charge quickly, last all day, and boot up immediately. 1
#
# This little notebook has proven to be the perfect computer for my 9-year old.  He previously had a Lenovo Windows 8 based PC and it quickly became a headache to maintain / manage.  The Chromebook is easy to lock down and stays running at peak performance for extended periods.  Battery life is great and my son absolutely loves it.  I think one of the selling points for him is that it looks pretty similar to my MacBook Pro's which certainly doesn't hurt. 1
#
# I use the Chromebook all the time at home, and when I am looking to surf the web or do relatively light computing. It has an amazing battery life, and the need to be connected to WiFi isn't that big a deal - there are hot spots nearly everywhere you go, and I also have a mobile WiFi hot spot from my phone provider. While limited apps and lack of internal storage and a thin OS limits the usefulness of the Chromebook, the use of the cloud computing resources from Google, coupled with the very low cost, makes this a good value and worth picking up as a second machine. 1
#
# I was not super impressed with the Samsung Chromebook right out the box and at first glance it looked cheap, but as soon asI opened it up that all changed the keyboard looks solid like a macbook and once you fire it up, its instantly on, Chrome is a solid OS it works and having everything in the cloud makes it easy too use with no chance of viruses. I noticed after getting this i rarely use my Ipad any more. This laptop gives me a better feel of the internet and is portable enough to take anywhere. Highly recommend it and it is my favorite gadget as of 3/21/13. 1
#
# I love the chromebook for travel - it's small, it's light, and it's got a very nice keyboard so I can actually type long email messages or other documents while traveling for business.When I'm traveling I don't need a whole lot of storage - enough of my life has moved to the cloud that I can do all my travel essentials on a chromebook that are unwieldy on my Android phone, and not worth lugging the poundage of a full laptop:  I can check Yelp for restaurants and book on OpenTable or UrbanSpoon, I can check all my travel plans on TripIt, I can check work and personal email and actually respond without struggling with screen-based keyboard on my phone or tablet (Nexus 7), I can listen to my music on Google or on Pandora, I can watch streamed movies, or even downloaded ones saved either to the device or an SD card.And the price point ($249 for mine) is amazing - get one for every member of your family for the lowest priced AirBook.My Chromebook is my new, light, small travel buddyIt honestly obsoletes my old laptop - now I have to figure out what to do with that monster. 1
#
# Surprised how light and functional the device is.  Much better design than Apple or other laptops, love the extra large track pad.I would use the supplied Chrome OS for a while, but could look to install a real distro (SuSE, Fedora, or Scientific GNU/Linux) sometime in near future.  Extremely quite, seems to have NO FANS or other moving parts (other than the hinge to open it) whatsoever.I would like a little more storage, but 16 gig should be enough, as long I keep track of what I need and can get web access to dropbox. 1

# %%
for summa in textrank_summa_neg.split('.')[:-1]:
    row = product_review.loc[product_review['clean_text'] == summa.strip()]
    text = row['reviewText'].iloc[0]
    label = row['label'].iloc[0]
    print(text,label,'\n')
# Out:
# My old Samsung Chromebook, Model 500c June/2011, works just fine anywhere in the house.  But my two tries for the new Model 303C cannot pick up WiFi quickly or even at all sometimes.  I tried to contact a person regarding this problem, but that's impossible so the only way to communicate a problem is to return the item.  I love ChromeOS, even use it on my MacAir.  It's too bad, I like the style and keyboard of the new 303C but I can't stand the WiFi connect problem. 0
#
# This laptop does everything it says it will do. Don't expect to get much else use out of it other than basic internet browsing. Also, mine only lasted a year before I began having issues with it turning on (only a white, pixelated screen would show up). If you need to just check e-mail, edit documents on Google Drive (and Google Drive only), and surf the web, then you'd be pretty satisfied with this little thing. Otherwise, look elsewhere. 0
#
# A problem with WEP router incryption has rendered my new Chromebook almost useless.Although I am greatful for the Chrome software as well as Google Drive and Google Docs allowing me drop Microsoft Office completely, I have had to use them from my old windows laptop, as my new Chromebook is completely unreliable. After an hour or too of happy, zippy, carefree use, on any given day, and almost anywhere, it will start having problems loading websites.The Chromebook Groups and support personel say if you can change the security on your router, the situation improvesAs I am not able to change the security on my family or work router, or at the local coffee shop or McDonalds, I have not been able to check their recommendationThey also suggest disabling the DNS Pre-fetchif you know what that is, you may be able to take advantage of their adviceI don'tI would recommend waiting until they work out this problem 0
#
# I am very disappointed with the chromebook.  I was hoping to replace my laptop computer, but so far this device cannot stream netflix or amazon videos.  I love it otherwise, it is small and light and boots up so quickly.  I was also hoping to use it to transfer pictures from my camera to the cloud drive, but this is either impossible or difficult to figure out - I spent a few hours trying the other night and was unsuccessful. 0
#
# My husband heard about this computer through friends who raved about how inexpensive it is also how easy it is to throw in a bag and go its very light lighter than 1/2 of most textbooks. I love how thin and sleek it is however that also has its disadvantages such as, It scratches very easily I have several scratches on mine and I seldom use it. Its definatley not child friendly as it is confusing to navigate once you are used to a windows system or such. I still cannot get over how nice the keyboard feels to my fingers they just sorta glide around I do enjoy the ease of that. I would not reccomend this to anyone with slow or dial up internet I have high speed wifi and it freezes alot on youtube and facebook. Most importantly it is  not currently able to stream videos and that is a huge dissapointment to me as I like to use netflix and sometimes when out of town or laying in bed I enjoy picking a good movie however, chrome is working on this issue and realize this is an inconvienence by all means so in my opinion cute light wish there was a stronger material and easier to navigate thanks for listening hope it helps :) 0
#
# I'm  a college student and got this at the begging of the school year and about 3 months after i got it, the screen cracked, there wasn't even any rough handling or dropping or spills just in my back pack as i walked around campus and the delicate flower of a laptop cracked i opened it up to do notes and it was unusable. the chrome operating system however was quick and everything i could want out of an operating system. but the Shoddy craftsmanship delivered to me by Samsung was ABYSMALLY DISAPPOINTING i would rather have two tickets to a movie which is worth a tenth of the price, if you enjoy throwing money away this is the product for you otherwise get something a little sturdier; i'm lucky because i actually had a back up laptop that I've had for about 3 years which has sustained numerous drops and abuse like a laptop is suposed to do if you've owned a laptop you know a drop is imminent it's going to slip or get pushed or somehting, accidents happen. and need i remind you I DIDN'T EVEN DROP IT.IN SUMMARYDO NOT BUY THIS PRODUCT, unless you want to get totally screwed over and swindled out of your money because drops aren't protected under normal warranty they do offer protection for additional 60 bucks but with how fragile it is i'm sure you'd just be put into a hassle as you have to send it in and get it repaired which is likely to be a couple shipping repair and then shipping it back in which time you're just up a creek without a paddle while you twiddle your thumbs waiting for your now 300$ computer to be daintily shipped back to you. 0
#
# I got the chromebook to replace a broken laptop and am SO unsatisfied. Among my complaints is it's lack of ability to run so many programs I find useful. These include everything from a good PDF reader (the only one available does not allow you to skip pages or anything, making scanning or searching pdfs unbearable), despite what some people say I find it pretty useless offline, the games and entertainment available is garbage compared to whats out there for a windows  or mac machine, and it just so LIMITED. THe price is NOT right when you think that's what you get for such a cheap laptop. You can get an older Windows or Mac laptop (or even LINUX is more useful) with a ton more utility. 0
#
# Sorry I can't say much about this product since I returned it as soon I received it. It wasn't until I placed my order that I noticed I won't be able to use it in connection to a smart boars. Additionally figuring out how to download macrosoft office was going to be a challenge since it was no hard drive. I like the size and the weight a lot, but this version wasn't a good fit for my needs. 0
#
# I bought the Samsung Chromebook becasue I wanted a laptop, the price was right and it looked nice.  I then got it, and sadly there was no mention that there was no disc drive, nor could you play games, or even use itunes.  This was just wrong.  I immediately packed it back up and sent it back.  Something like this should be told. 0
#
# I enjoyed this product for the same reasons other reviewers have given - until the screen developed a defect after just a few months of use, and Samsung would not replace it or fix it (unless I paid them $250). The screen cracked under completely normal use, just sitting on my desk.I would strongly recommend against purchasing this laptop - it's cheap, but based on other similar complaints I've read the defect is very common, and I don't think it's worth it.Here's a picture of the defect: [.]Here's a picture of the warranty document showing why it's not covered: [.] 0
